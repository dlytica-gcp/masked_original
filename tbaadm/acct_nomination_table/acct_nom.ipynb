# %%
import pandas as pd
df_acct_nom= pd.read_csv("acct_nomination_table.csv")
df_acct_nom.head()
# Out:
#        acid  cif_id  nom_id  ts_cnt  bank_id del_flg  nom_amt  \
# 0   0147135     NaN       1       0        1       N        0
# 1  02179459     NaN       1       0        1       N        0
# 2  02179560     NaN       1       0        1       N        0
# 3  01181737     NaN       1       0        1       N        0
# 4  02182520     NaN       1       0        1       N        0
#
#                  nom_name  nom_pcnt            lchg_time  ...  \
# 0    Shreya Devi Bhandari       100  2009-03-29T14:14:55  ...
# 1         Sunita Maya Rai       100  2011-05-16T12:20:23  ...
# 2       Sapana Devi Thapa       100  2011-05-16T16:42:10  ...
# 3  Sabita Kumari Bhandari       100  2011-06-06T17:40:04  ...
# 4      Sabita Laxmi Thapa       100  2011-06-14T14:20:15  ...
#
#   pref_lang_nom_name nom_guard_city_code  nom_wit1_cntry_code  \
# 0                NaN                 NaN                  NaN
# 1                NaN                 NaN                  NaN
# ...

# %%
df_gam=pd.read_csv("../general_acct_mast_table/general_acct_mast_table_masked.csv")
df_gam.head()
# Out:
#          acid      acid_t     cif_id           foracid           foracid_t  \
# 0   Q39620558  AC83477802  R02944296  2635752944296001  FA3683176010178129
# 1  Y110180600  AC28966287  O99520992  3414659520992004  FA9480299565595898
# 2   O93531058  AC98636744  O99520992  O987952099252401  FA7106544699531866
# 3    32559774  AC72858901  R32157797  3241157797524004  FA1631713350235916
# 4   889280082  AC73874192  R09092002  0884459092002067  FA2641279335334283
#
#        acct_num                   acct_name  \
# 0  831760101781     Humacanta Prasad Pandey
# 1  802995655958       Sriti Saraswati Limbu
# 2   65446995318       Sriti Saraswati Limbu
# 3  317133502359  PALPA HEALTHCARE PVT. LTD.
# 4  412793353342                         NaN
#
#                                   hashed_no        phone_num  \
# 0  C1426B129652A7DB20182EAE18980F1B26D3B17E       9829243528
# 1  26B23D96EE13CDC789D531D4CF5839AD1EF73B75              NaN
# ...

# %%
df_result = pd.merge(df_acct_nom, df_gam, how='left', on='acid',suffixes=('_p', '_a'))
df_result.head(10)
# Out:
#        acid  cif_id_p  nom_id  ts_cnt_p  bank_id_p del_flg_p  nom_amt  \
# 0   0147135       NaN       1         0          1         N        0
# 1  02179459       NaN       1         0          1         N        0
# 2  02179560       NaN       1         0          1         N        0
# 3  01181737       NaN       1         0          1         N        0
# 4  02182520       NaN       1         0          1         N        0
# 5  01213715       NaN       1         0          1         N        0
# 6  02244385       NaN       1         0          1         N        0
# 7  01238069       NaN       1         3          1         N        0
# 8  33460134       NaN       1         0          1         N        0
# 9  15384340       NaN       1         0          1         N        0
#
#                  nom_name  nom_pcnt          lchg_time_p  ...  \
# 0    Shreya Devi Bhandari       100  2009-03-29T14:14:55  ...
# 1         Sunita Maya Rai       100  2011-05-16T12:20:23  ...
# ...

# %%
print(df_acct_nom.shape)
print(df_result.shape)
# Out:
# (2461, 53)
# (2461, 242)

# %%
df_acct_nom[['acid','cif_id']]=df_result[['acid_t','cif_id_t']]
df_acct_nom.head()
# Out:
#          acid         cif_id  nom_id  ts_cnt  bank_id del_flg  nom_amt  \
# 0  AC99691567  DLNIND7460353       1       0        1       N        0
# 1  AC75397150  DLNIND4948337       1       0        1       N        0
# 2  AC52910315  DLNIND4948337       1       0        1       N        0
# 3  AC39953621  DLNIND7460353       1       0        1       N        0
# 4  AC27967147  DLNIND4948337       1       0        1       N        0
#
#                  nom_name  nom_pcnt            lchg_time  ...  \
# 0    Shreya Devi Bhandari       100  2009-03-29T14:14:55  ...
# 1         Sunita Maya Rai       100  2011-05-16T12:20:23  ...
# 2       Sapana Devi Thapa       100  2011-05-16T16:42:10  ...
# 3  Sabita Kumari Bhandari       100  2011-06-06T17:40:04  ...
# 4      Sabita Laxmi Thapa       100  2011-06-14T14:20:15  ...
#
#   pref_lang_nom_name nom_guard_city_code  nom_wit1_cntry_code  \
# 0                NaN                 NaN                  NaN
# ...

# %%
df_acct_nom.to_csv("acct_nomination_table_masked.csv",index=False)
