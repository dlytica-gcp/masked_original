# %%
import pandas as pd

# %%
df_eod_acct_bal= pd.read_excel("eod_acct_bal_table.xlsx")
df_eod_acct_bal.head()
# Out:
#        acid               eod_date  tran_date_bal  tran_date_tot_tran  \
# 0  01238069  2024-02-04 00:00:00.0      202248.70                 0.0
# 1  02264368  2024-02-01 00:00:00.0       26572.44                 0.0
# 2  02264368  2024-06-01 00:00:00.0       26586.20                 0.0
# 3  02559106  2024-04-01 00:00:00.0      423183.63            348542.0
# 4  02559220  2024-06-01 00:00:00.0       10000.00                 0.0
#
#    value_date_bal  value_date_tot_tran           end_eod_date lchg_user_id  \
# 0       202248.70                  0.0  2024-02-11 00:00:00.0     FINADMIN
# 1        26572.44                  0.0  2024-02-01 00:00:00.0     FINADMIN
# 2        26586.20                  0.0  2024-06-01 00:00:00.0       SYSTEM
# 3       423183.63             348542.0  2024-04-01 00:00:00.0     FINADMIN
# 4        10000.00                  0.0  2024-06-01 00:00:00.0       SYSTEM
#
#                lchg_time rcre_user_id  ... ts_cnt  eab_crncy_code bank_id  \
# 0  2024-02-13 02:08:55.0     FINADMIN  ...      1             NPR       1
# 1  2024-02-02 22:16:09.0     FINADMIN  ...      1             NPR       1
# 2  2024-06-02 19:41:37.0       SYSTEM  ...      2             NPR       1
# 3  2024-04-02 23:53:50.0     FINADMIN  ...      1             NPR       1
# 4  2024-06-02 19:41:31.0       SYSTEM  ...      2             NPR       1
#
#    last_pstd_srl_num  last_tran_sequence_num  tran_count  \
# 0                  0                       0           0
# 1                  0                       0           0
# 2                  0                       0           0
# 3                  0                       0           0
# 4                  0                       0           0
#
#                updated_at  year  month  day
# 0 2024-07-30 11:45:30.870  2024      2    4
# 1 2024-07-30 11:45:30.870  2024      2    1
# 2 2024-07-30 11:45:30.870  2024      6    1
# 3 2024-07-30 11:45:30.870  2024      4    1
# 4 2024-07-30 11:45:30.870  2024      6    1
#
# [5 rows x 21 columns]

# %%
df_gam = pd.read_csv("../general_acct_mast_table/acid_foracid_masked.csv")
df_gam.head()
# Out:
#          acid      acid_t         cif_id           foracid  \
# 0   Q39620558  AC10370877  DLNIND1406504  2635752944296001
# 1  Y110180600  AC41672289  DLNIND4211643  3414659520992004
# 2   O93531058  AC73584145  DLNIND4211643  O987952099252401
# 3    32559774  AC12345718  DLNLEG9334212  3241157797524004
# 4   889280082  AC47235600  DLNLEG6576494  0884459092002067
#
#             foracid_t           pan      acct_num                   acct_name
# 0  FA9627239668220084  PAN668645879  272396682200       Humacanta Bipin Thapa
# 1  FA3302344775994664  PAN697945863   23447759946          Sriti Kumari Thapa
# 2  FA5553585851915269  PAN697945863  535858519152          Sriti Kumari Thapa
# 3  FA2582732553674743  PAN353089449  827325536747  PALPA HEALTHCARE PVT. LTD.
# 4  FA7171012596574289  PAN813377590  710125965742                         NaN

# %%
df_result = pd.merge(df_eod_acct_bal, df_gam, how='left', on='acid',suffixes=('_p', '_a'))
df_result.head()
# Out:
#        acid               eod_date  tran_date_bal  tran_date_tot_tran  \
# 0  01238069  2024-02-04 00:00:00.0      202248.70                 0.0
# 1  02264368  2024-02-01 00:00:00.0       26572.44                 0.0
# 2  02264368  2024-06-01 00:00:00.0       26586.20                 0.0
# 3  02559106  2024-04-01 00:00:00.0      423183.63            348542.0
# 4  02559220  2024-06-01 00:00:00.0       10000.00                 0.0
#
#    value_date_bal  value_date_tot_tran           end_eod_date lchg_user_id  \
# 0       202248.70                  0.0  2024-02-11 00:00:00.0     FINADMIN
# 1        26572.44                  0.0  2024-02-01 00:00:00.0     FINADMIN
# 2        26586.20                  0.0  2024-06-01 00:00:00.0       SYSTEM
# 3       423183.63             348542.0  2024-04-01 00:00:00.0     FINADMIN
# 4        10000.00                  0.0  2024-06-01 00:00:00.0       SYSTEM
#
#                lchg_time rcre_user_id  ...  year  month day      acid_t  \
# 0  2024-02-13 02:08:55.0     FINADMIN  ...  2024      2   4  AC90312813
# 1  2024-02-02 22:16:09.0     FINADMIN  ...  2024      2   1  AC50755170
# 2  2024-06-02 19:41:37.0       SYSTEM  ...  2024      6   1  AC50755170
# 3  2024-04-02 23:53:50.0     FINADMIN  ...  2024      4   1  AC38803203
# 4  2024-06-02 19:41:31.0       SYSTEM  ...  2024      6   1  AC73089441
#
#           cif_id           foracid           foracid_t           pan  \
# 0  DLNIND5576304  0114082803524001  FA2906806183611612  PAN747150056
# 1  DLNLEG5063780  0219240201524001  FA5809106809503348  PAN642854936
# 2  DLNLEG5063780  0219240201524001  FA5809106809503348  PAN642854936
# 3  DLNLEG3286748  0241103112524006  FA4669391728784622  PAN903432729
# 4  DLNLEG5063780  0241240201524004  FA6552847506759018  PAN642854936
#
#        acct_num         acct_name
# 0   68061836116  Lucy Laxmi Regmi
# 1   91068095033               NaN
# 2   91068095033               NaN
# 3  693917287846               NaN
# 4  528475067590               NaN
#
# [5 rows x 28 columns]

# %%
print(df_eod_acct_bal.shape)
print(df_result.shape)
# Out:
# (2009, 21)
# (2009, 28)

# %%
df_eod_acct_bal["acid"] = df_result["acid_t"].values
df_eod_acct_bal.head()
# Out:
#          acid               eod_date  tran_date_bal  tran_date_tot_tran  \
# 0  AC90312813  2024-02-04 00:00:00.0      202248.70                 0.0
# 1  AC50755170  2024-02-01 00:00:00.0       26572.44                 0.0
# 2  AC50755170  2024-06-01 00:00:00.0       26586.20                 0.0
# 3  AC38803203  2024-04-01 00:00:00.0      423183.63            348542.0
# 4  AC73089441  2024-06-01 00:00:00.0       10000.00                 0.0
#
#    value_date_bal  value_date_tot_tran           end_eod_date lchg_user_id  \
# 0       202248.70                  0.0  2024-02-11 00:00:00.0     FINADMIN
# 1        26572.44                  0.0  2024-02-01 00:00:00.0     FINADMIN
# 2        26586.20                  0.0  2024-06-01 00:00:00.0       SYSTEM
# 3       423183.63             348542.0  2024-04-01 00:00:00.0     FINADMIN
# 4        10000.00                  0.0  2024-06-01 00:00:00.0       SYSTEM
#
#                lchg_time rcre_user_id  ... ts_cnt  eab_crncy_code bank_id  \
# 0  2024-02-13 02:08:55.0     FINADMIN  ...      1             NPR       1
# 1  2024-02-02 22:16:09.0     FINADMIN  ...      1             NPR       1
# 2  2024-06-02 19:41:37.0       SYSTEM  ...      2             NPR       1
# 3  2024-04-02 23:53:50.0     FINADMIN  ...      1             NPR       1
# 4  2024-06-02 19:41:31.0       SYSTEM  ...      2             NPR       1
#
#    last_pstd_srl_num  last_tran_sequence_num  tran_count  \
# 0                  0                       0           0
# 1                  0                       0           0
# 2                  0                       0           0
# 3                  0                       0           0
# 4                  0                       0           0
#
#                updated_at  year  month  day
# 0 2024-07-30 11:45:30.870  2024      2    4
# 1 2024-07-30 11:45:30.870  2024      2    1
# 2 2024-07-30 11:45:30.870  2024      6    1
# 3 2024-07-30 11:45:30.870  2024      4    1
# 4 2024-07-30 11:45:30.870  2024      6    1
#
# [5 rows x 21 columns]

# %%
df_eod_acct_bal.to_csv("eod_acct_bal_table.masked.csv",index=False)
