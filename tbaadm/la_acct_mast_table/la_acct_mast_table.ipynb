# %%
import pandas as pd
df_la_acct_mast= pd.read_excel("la_acct_mast_table.xlsx")
df_la_acct_mast.head()
# Out:
#         acid  ts_cnt  bank_id del_flg    dis_amt    op_acid  eir_rate  \
# 0  B95756817     225        1       N  4500000.0  B95745502         0
# 1  707601829     139        1       N  4000000.0  704009981         0
# 2  H88761015      61        1       N  3400000.0  H88727279         0
# 3  D88097098      47        1       N  1500000.0  D86314215         0
# 4  D88462761      66        1       N  1500000.0  D86314215         0
#
#    acct_type  dealer_id ei_method  ... penal_int_grace_perd_days  \
# 0        NaN        NaN         R  ...                       0.0
# 1        NaN        NaN         R  ...                       0.0
# 2        NaN        NaN            ...                       0.0
# 3        NaN        NaN            ...                       0.0
# 4        NaN        NaN            ...                       0.0
#
#   penal_int_grace_perd_mths  crystallisation_time_stamp  \
# 0                       0.0                         NaN
# ...

# %%
df_gam=pd.read_csv("../general_acct_mast_table/general_acct_mast_table_masked.csv")
df_gam.head()
# Out:
#          acid      acid_t     cif_id           foracid           foracid_t  \
# 0   Q39620558  AC83477802  R02944296  2635752944296001  FA3683176010178129
# 1  Y110180600  AC28966287  O99520992  3414659520992004  FA9480299565595898
# 2   O93531058  AC98636744  O99520992  O987952099252401  FA7106544699531866
# 3    32559774  AC72858901  R32157797  3241157797524004  FA1631713350235916
# 4   889280082  AC73874192  R09092002  0884459092002067  FA2641279335334283
#
#        acct_num                   acct_name  \
# 0  831760101781     Humacanta Prasad Pandey
# 1  802995655958       Sriti Saraswati Limbu
# 2   65446995318       Sriti Saraswati Limbu
# 3  317133502359  PALPA HEALTHCARE PVT. LTD.
# 4  412793353342                         NaN
#
#                                   hashed_no        phone_num  \
# 0  C1426B129652A7DB20182EAE18980F1B26D3B17E       9829243528
# 1  26B23D96EE13CDC789D531D4CF5839AD1EF73B75              NaN
# ...

# %%
df_result = pd.merge(df_la_acct_mast, df_gam, how='left', on='acid',suffixes=('_p', '_a'))
df_result.head(10)
# Out:
#          acid  ts_cnt_p  bank_id_p del_flg_p     dis_amt    op_acid  eir_rate  \
# 0   B95756817       225          1         N  4500000.00  B95745502         0
# 1   707601829       139          1         N  4000000.00  704009981         0
# 2   H88761015        61          1         N  3400000.00  H88727279         0
# 3   D88097098        47          1         N  1500000.00  D86314215         0
# 4   D88462761        66          1         N  1500000.00  D86314215         0
# 5   V78267731        68          1         N  4700000.00  V75502574         0
# 6  1510412040        12          1         N     4059.75  153396015         0
# 7   385811456       257          1         N  2000000.00  385749998         0
# 8   223691552       334          1         N  1788000.00   22562003         0
# 9   D89891226        32          1         N  1500000.00  D86314215         0
#
#    acct_type  dealer_id ei_method  ... acct_cls_advice_printed  \
# ...

# %%
print(df_la_acct_mast.shape)
print(df_result.shape)
# Out:
# (721, 231)
# (721, 420)

# %%
df_la_acct_mast['acid']=df_result['acid_t'].values
df_la_acct_mast.head()
# Out:
#          acid  ts_cnt  bank_id del_flg    dis_amt    op_acid  eir_rate  \
# 0  AC27364136     225        1       N  4500000.0  B95745502         0
# 1  AC15071859     139        1       N  4000000.0  704009981         0
# 2  AC11235070      61        1       N  3400000.0  H88727279         0
# 3  AC66893611      47        1       N  1500000.0  D86314215         0
# 4  AC44054040      66        1       N  1500000.0  D86314215         0
#
#    acct_type  dealer_id ei_method  ... penal_int_grace_perd_days  \
# 0        NaN        NaN         R  ...                       0.0
# 1        NaN        NaN         R  ...                       0.0
# 2        NaN        NaN            ...                       0.0
# 3        NaN        NaN            ...                       0.0
# 4        NaN        NaN            ...                       0.0
#
#   penal_int_grace_perd_mths  crystallisation_time_stamp  \
# 0                       0.0                         NaN
# ...

# %%
df_la_acct_mast.to_csv("la_acct_mast_table_masked.csv",index=False)
