# %%
import pandas as pd
dc_mast_main_table= pd.read_excel("dc_mast_main_table.xlsx")
# dc_mast_main_table = dc_mast_main_table.drop(['_airbyte_ab_id', '_airbyte_emitted_at',"source_file_path","_airbyte_additional_properties"], axis=1)

dc_mast_main_table.head()
# Out:
#       rate  sol_id  ts_cnt  bank_id del_flg  dc_b2kid  insu_amt  insu_num  \
# 0  79.2000       4      14        1       N   DC09468         0       NaN
# 1  79.2000       4      14        1       N   DC09469         0       NaN
# 2   1.6015       4      13        1       N  DC101348         0       NaN
# 3   1.6015       2      21        1       N  DC132767         0       NaN
# 4   1.6015       2       8        1       N  DC133113         0       NaN
#
#   ratecode                   date_clsd  ... interest_nobill_util_amt  \
# 0      SEL  2010-09-15T00:00:00.000000  ...                      NaN
# 1      SEL  2010-09-15T00:00:00.000000  ...                      NaN
# 2      SEL                         NaN  ...                      NaN
# 3      SEL                         NaN  ...                      NaN
# 4      SEL                         NaN  ...                      NaN
#
#   interest_reinstament_amt  mtmd_margin_referred_flg murbaha_third_party_acid  \
# ...

# %%
dc_mast_main_table.to_csv("dc_mast_main_table_masked.csv",index=False)
