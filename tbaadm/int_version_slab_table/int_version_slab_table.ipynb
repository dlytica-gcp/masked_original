# %%
import pandas as pd
df_int_version_slab= pd.read_excel("int_version_slab_table.xlsx")
df_int_version_slab.head()
# Out:
#    ts_cnt  bank_id del_flg            lchg_time            rcre_time  \
# 0       1        1       N  2024-08-17T11:21:51  2024-08-17T11:17:02
# 1       1        1       N  2024-08-17T11:22:35  2024-08-17T11:17:02
# 2       1        1       N  2024-08-17T11:23:12  2024-08-17T11:17:02
# 3       1        1       N  2024-08-17T11:25:10  2024-08-17T11:17:03
# 4       1        1       N  2024-08-17T11:26:08  2024-08-17T11:17:03
#
#   crncy_code  end_slab_amt int_tbl_code lchg_user_id  qis_int_pcnt  ...  \
# 0        NPR  1.000000e+14        SBKBK       SB3610             0  ...
# 1        NPR  1.000000e+14        SD006       SB3610             0  ...
# 2        NPR  1.000000e+14        SBDBS       SB3610             0  ...
# 3        NPR  1.000000e+14        SD020       SB3610             0  ...
# 4        NPR  1.000000e+14        SD031       SB3610             0  ...
#
#   penal_int_pcnt  int_tbl_ver_num  qis_portion_ind  int_slab_srl_num  \
# ...

# %%
df_int_version_slab.to_csv("int_version_slab_table_masked.csv",index=False)
