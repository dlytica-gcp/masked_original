# %%
import pandas as pd
bg_event_table= pd.read_excel("bg_event_table.xlsx")
bg_event_table = bg_event_table.drop(['_airbyte_ab_id', '_airbyte_emitted_at',"source_file_path","_airbyte_additional_properties"], axis=1)

bg_event_table.head()
# Out:
#   rmks     bg_amt  ts_cnt  bank_id  disb_id bg_b2kid     event_id amend_ind  \
# 0  NaN  5000000.0       0        1      NaN   DC0896    BGCHARGES       NaN
# 1  NaN  5000000.0       0        1      NaN   DC0896    BGCHARGES       NaN
# 2  NaN  5000000.0       0        1      NaN   DC0896    BGCHARGES       NaN
# 3  NaN  5000000.0       0        1      NaN   DC0896    BGCHARGES       NaN
# 4  NaN   200000.0       0        1      NaN  DC09168  BGCHARGESBB       NaN
#
#   bg_status  event_amt  ... auto_renew_next_cycle instlmnt_freq_start_dd  \
# 0         A  5000000.0  ...                   NaN                      0
# 1         A        0.0  ...                   NaN                      0
# 2         A        0.0  ...                   NaN                      0
# 3         A        0.0  ...                   NaN                      0
# 4         E   200000.0  ...                   NaN                      0
#
#   instlmnt_freq_week_day instlmnt_freq_week_num auto_renew_freq_week_dd  \
# 0                      0                    NaN                     NaN
# 1                      0                    NaN                     NaN
# 2                      0                    NaN                     NaN
# 3                      0                    NaN                     NaN
# 4                      0                    NaN                     NaN
#
#   auto_renew_freq_cal_base  auto_renew_freq_week_day auto_renew_freq_week_num  \
# 0                      NaN                       NaN                      NaN
# 1                      NaN                       NaN                      NaN
# 2                      NaN                       NaN                      NaN
# 3                      NaN                       NaN                      NaN
# 4                      NaN                       NaN                      NaN
#
#    auto_renew_applicable_flg              updated_at
# 0                          N 2024-08-07 06:41:56.805
# 1                          N 2024-08-07 06:41:56.805
# 2                          N 2024-08-07 06:41:56.805
# 3                          N 2024-08-07 06:41:56.805
# 4                          N 2024-08-07 06:41:56.805
#
# [5 rows x 62 columns]
