# %%
import pandas as pd
df_la_dmd_adj= pd.read_excel("la_dmd_adj_table.xlsx")
df_la_dmd_adj.head()
# Out:
#          acid  ts_cnt   adj_amt  bank_id del_flg  srl_num    tran_id  \
# 0  2210369522       0  12306.85        1       N        1  S21514505
# 1   225758079       0  36837.99        1       N        1  S21514531
# 2   227610563       0  15152.66        1       N        1  S21514563
# 3   305913285       0     23.30        1       N        1  S21525566
# 4   309658898       0    143.65        1       N        1  S21525582
#
#                      adj_date                    dmd_date  shdl_num  ...  \
# 0  2024-08-01T00:00:00.000000  2024-08-01T00:00:00.000000         1  ...
# 1  2024-08-01T00:00:00.000000  2024-08-01T00:00:00.000000         4  ...
# 2  2024-08-01T00:00:00.000000  2024-08-01T00:00:00.000000         3  ...
# 3  2024-08-01T00:00:00.000000  2024-08-01T00:00:00.000000         3  ...
# 4  2024-08-01T00:00:00.000000  2024-08-01T00:00:00.000000         1  ...
#
#                     tran_date dmd_flow_id dmd_srl_num lchg_user_id  \
# ...

# %%
df_gam=pd.read_csv("../general_acct_mast_table/general_acct_mast_table_masked.csv")
df_gam.head()
# Out:
#          acid      acid_t     cif_id           foracid           foracid_t  \
# 0   Q39620558  AC83477802  R02944296  2635752944296001  FA3683176010178129
# 1  Y110180600  AC28966287  O99520992  3414659520992004  FA9480299565595898
# 2   O93531058  AC98636744  O99520992  O987952099252401  FA7106544699531866
# 3    32559774  AC72858901  R32157797  3241157797524004  FA1631713350235916
# 4   889280082  AC73874192  R09092002  0884459092002067  FA2641279335334283
#
#        acct_num                   acct_name  \
# 0  831760101781     Humacanta Prasad Pandey
# 1  802995655958       Sriti Saraswati Limbu
# 2   65446995318       Sriti Saraswati Limbu
# 3  317133502359  PALPA HEALTHCARE PVT. LTD.
# 4  412793353342                         NaN
#
#                                   hashed_no        phone_num  \
# 0  C1426B129652A7DB20182EAE18980F1B26D3B17E       9829243528
# 1  26B23D96EE13CDC789D531D4CF5839AD1EF73B75              NaN
# ...

# %%
df_result = pd.merge(df_la_dmd_adj, df_gam, how='left', on='acid',suffixes=('_p', '_a'))
df_result.head(10)
# Out:
#          acid  ts_cnt_p   adj_amt  bank_id_p del_flg_p  srl_num    tran_id  \
# 0  2210369522         0  12306.85          1         N        1  S21514505
# 1   225758079         0  36837.99          1         N        1  S21514531
# 2   227610563         0  15152.66          1         N        1  S21514563
# 3   305913285         0     23.30          1         N        1  S21525566
# 4   309658898         0    143.65          1         N        1  S21525582
# 5   U96294799         0  14664.70          1         N        1  S21526281
# 6   U96294799         0   9004.61          1         N        1  S21526490
# 7   385811456         0    124.15          1         N        1  S21532993
# 8   707601829         0     55.70          1         N        1  S21547395
# 9   471329410         0   2114.42          1         N        1  S21547413
#
#                      adj_date                    dmd_date  shdl_num  ...  \
# ...

# %%
print(df_la_dmd_adj.shape)
print(df_result.shape)
# Out:
# (1037, 22)
# (1037, 211)

# %%
df_la_dmd_adj['acid']=df_result['acid_t'].values
df_la_dmd_adj.head()
# Out:
#          acid  ts_cnt   adj_amt  bank_id del_flg  srl_num    tran_id  \
# 0  AC84692100       0  12306.85        1       N        1  S21514505
# 1  AC84517231       0  36837.99        1       N        1  S21514531
# 2  AC38297548       0  15152.66        1       N        1  S21514563
# 3  AC30759555       0     23.30        1       N        1  S21525566
# 4  AC68768599       0    143.65        1       N        1  S21525582
#
#                      adj_date                    dmd_date  shdl_num  ...  \
# 0  2024-08-01T00:00:00.000000  2024-08-01T00:00:00.000000         1  ...
# 1  2024-08-01T00:00:00.000000  2024-08-01T00:00:00.000000         4  ...
# 2  2024-08-01T00:00:00.000000  2024-08-01T00:00:00.000000         3  ...
# 3  2024-08-01T00:00:00.000000  2024-08-01T00:00:00.000000         3  ...
# 4  2024-08-01T00:00:00.000000  2024-08-01T00:00:00.000000         1  ...
#
#                     tran_date dmd_flow_id dmd_srl_num lchg_user_id  \
# ...

# %%
df_la_dmd_adj.to_csv("la_dmd_adj_table_masked.csv",index=False)
