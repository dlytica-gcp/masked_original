# %%
import pandas as pd
df_ccod_acct_mast= pd.read_excel("ccod_acct_mast_table.xlsx")
df_ccod_acct_mast.head()
# Out:
#        acid  ts_cnt  bank_id del_flg disb_ind  due_date            lchg_time  \
# 0   0147135       2        1       N      NaN       NaN  2010-04-12T18:03:44
# 1  01139294       0        1       N        M       NaN  2010-06-23T12:37:27
# 2  01165109       0        1       N        M       NaN  2011-01-14T16:33:57
# 3  02179459       0        1       N      NaN       NaN  2011-05-16T12:20:21
# 4  01196977       0        1       N        M       NaN  2011-10-17T21:15:37
#
#              rcre_time acct_status  delink_acid  ... adj_for_closure_flg  \
# 0  2009-03-29T14:14:55           A          NaN  ...                 NaN
# 1  2010-06-23T12:37:27           A          NaN  ...                 NaN
# 2  2011-01-14T16:33:57           A          NaN  ...                 NaN
# 3  2011-05-16T12:20:21           A          NaN  ...                 NaN
# 4  2011-10-17T21:15:37           A          NaN  ...                 NaN
#
# ...

# %%
df_gam=pd.read_csv("../general_acct_mast_table/general_acct_mast_table_masked.csv")
df_gam.head()
# Out:
#          acid      acid_t     cif_id           foracid           foracid_t  \
# 0   Q39620558  AC83477802  R02944296  2635752944296001  FA3683176010178129
# 1  Y110180600  AC28966287  O99520992  3414659520992004  FA9480299565595898
# 2   O93531058  AC98636744  O99520992  O987952099252401  FA7106544699531866
# 3    32559774  AC72858901  R32157797  3241157797524004  FA1631713350235916
# 4   889280082  AC73874192  R09092002  0884459092002067  FA2641279335334283
#
#        acct_num                   acct_name  \
# 0  831760101781     Humacanta Prasad Pandey
# 1  802995655958       Sriti Saraswati Limbu
# 2   65446995318       Sriti Saraswati Limbu
# 3  317133502359  PALPA HEALTHCARE PVT. LTD.
# 4  412793353342                         NaN
#
#                                   hashed_no        phone_num  \
# 0  C1426B129652A7DB20182EAE18980F1B26D3B17E       9829243528
# 1  26B23D96EE13CDC789D531D4CF5839AD1EF73B75              NaN
# ...

# %%
df_result = pd.merge(df_ccod_acct_mast, df_gam, how='left', on='acid',suffixes=('_p', '_a'))
df_result.head(10)
# Out:
#        acid  ts_cnt_p  bank_id_p del_flg_p disb_ind  due_date  \
# 0   0147135         2          1         N      NaN       NaN
# 1  01139294         0          1         N        M       NaN
# 2  01165109         0          1         N        M       NaN
# 3  02179459         0          1         N      NaN       NaN
# 4  01196977         0          1         N        M       NaN
# 5  01181737         2          1         N      NaN       NaN
# 6  32559773         0          1         N      NaN       NaN
# 7  30565652         0          1         N      NaN       NaN
# 8   0143753         8          1         N        M       NaN
# 9  09786725         0          1         N      NaN       NaN
#
#            lchg_time_p          rcre_time_p acct_status  delink_acid  ...  \
# 0  2010-04-12T18:03:44  2009-03-29T14:14:55           A          NaN  ...
# 1  2010-06-23T12:37:27  2010-06-23T12:37:27           A          NaN  ...
# ...

# %%
print(df_ccod_acct_mast.shape)
print(df_result.shape)
# Out:
# (123, 44)
# (123, 233)

# %%
df_ccod_acct_mast['acid']=df_result['acid_t']
df_ccod_acct_mast.head()
# Out:
#          acid  ts_cnt  bank_id del_flg disb_ind  due_date  \
# 0  AC99691567       2        1       N      NaN       NaN
# 1  AC36167844       0        1       N        M       NaN
# 2  AC38634323       0        1       N        M       NaN
# 3  AC75397150       0        1       N      NaN       NaN
# 4  AC99331848       0        1       N        M       NaN
#
#              lchg_time            rcre_time acct_status  delink_acid  ...  \
# 0  2010-04-12T18:03:44  2009-03-29T14:14:55           A          NaN  ...
# 1  2010-06-23T12:37:27  2010-06-23T12:37:27           A          NaN  ...
# 2  2011-01-14T16:33:57  2011-01-14T16:33:57           A          NaN  ...
# 3  2011-05-16T12:20:21  2011-05-16T12:20:21           A          NaN  ...
# 4  2011-10-17T21:15:37  2011-10-17T21:15:37           A          NaN  ...
#
#   adj_for_closure_flg  acct_cls_reason_code  collect_excess_profit  \
# 0                 NaN                   NaN                    NaN
# ...

# %%
df_ccod_acct_mast.to_csv("ccod_acct_mast_table_masked.csv",index=False)
