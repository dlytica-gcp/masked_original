# %%
import pandas as pd
df_crncy_schm_parm= pd.read_excel("crncy_schm_parm_tbl.xlsx")
df_crncy_schm_parm.head()
# Out:
#    TS_CNT  BANK_ID DEL_FLG WTAX_FLG            LCHG_TIME            RCRE_TIME  \
# 0       0        1       N      NaN  2007-09-21T12:52:40  2007-09-21T12:52:40
# 1       0        1       N      NaN  2007-09-21T12:52:40  2007-09-21T12:52:40
# 2       0        1       N      NaN  2007-09-21T12:52:40  2007-09-21T12:52:40
# 3       0        1       N      NaN  2007-09-21T12:52:40  2007-09-21T12:52:40
# 4       0        1       N      NaN  2007-09-21T12:52:40  2007-09-21T12:52:40
#
#   SCHM_CODE TDS_BACID  WTAX_PCNT    CLG_CR_LIM  ...  \
# 0     OAPDR       NaN          0  1.000000e+14  ...
# 1     OAPDR       NaN          0  1.000000e+14  ...
# 2     OAPDR       NaN          0  1.000000e+14  ...
# 3     OAPDR       NaN          0  1.000000e+14  ...
# 4     OAPDR       NaN          0  1.000000e+14  ...
#
#    DR_TRAN_NOT_ALWD_EXCP_CODE NOTC_CANCELLATION_EVENT_ID  \
# 0                         NaN                        NaN
# 1                         NaN                        NaN
# ...

# %%
df_crncy_schm_parm.to_csv("crncy_schm_parm_tbl_masked.csv",index=False)
