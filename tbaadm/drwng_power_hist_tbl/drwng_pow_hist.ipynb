# %%
import pandas as pd
df_drwng_pow_hist= pd.read_excel("drwng_power_hist_tbl.xlsx")
df_drwng_pow_hist.head()
# Out:
#       acid status  ts_cnt  bank_id del_flg remarks  dacc_lim  \
# 0  0113590      A       1        1       N     NaN         0
# 1  0113590      A       0        1       N     NaN         0
# 2  0113590      A       2        1       N     NaN         0
# 3  0115282      A       1        1       N     NaN         0
# 4  0115283      A       1        1       N     NaN         0
#
#                event_id            lchg_time            rcre_time  ...  \
# 0  0113590/000000000001  2008-08-27T16:19:02  2008-08-27T15:35:06  ...
# 1  0113590/000000000001  2008-09-09T18:08:56  2008-09-09T18:08:56  ...
# 2  0113590/000000000003  2008-09-09T18:55:16  2008-09-09T18:54:15  ...
# 3  0115282/000000000001  2008-09-10T14:28:40  2008-09-10T13:18:37  ...
# 4  0115283/000000000001  2008-09-10T14:29:58  2008-09-10T13:21:45  ...
#
#   lchg_user_id rcre_user_id dacc_lim_pcnt  dafa_lim_pcnt  tot_mod_times  \
# 0       SOPHYP       LAXMIS             0              0              0
# ...

# %%
df_gam=pd.read_csv("../general_acct_mast_table/acid_foracid_masked.csv")
df_gam.head()
# Out:
#          acid      acid_t         cif_id           foracid  \
# 0   Q39620558  AC10370877  DLNIND1406504  2635752944296001
# 1  Y110180600  AC41672289  DLNIND4211643  3414659520992004
# 2   O93531058  AC73584145  DLNIND4211643  O987952099252401
# 3    32559774  AC12345718  DLNLEG9334212  3241157797524004
# 4   889280082  AC47235600  DLNLEG6576494  0884459092002067
#
#             foracid_t           pan      acct_num                   acct_name
# 0  FA9627239668220084  PAN668645879  272396682200       Humacanta Bipin Thapa
# 1  FA3302344775994664  PAN697945863   23447759946          Sriti Kumari Thapa
# 2  FA5553585851915269  PAN697945863  535858519152          Sriti Kumari Thapa
# 3  FA2582732553674743  PAN353089449  827325536747  PALPA HEALTHCARE PVT. LTD.
# 4  FA7171012596574289  PAN813377590  710125965742                         NaN

# %%
df_result = pd.merge(df_drwng_pow_hist, df_gam, how='left', on='acid',suffixes=('_p', '_a'))
df_result.head(10)
# Out:
#       acid status  ts_cnt  bank_id del_flg remarks  dacc_lim  \
# 0  0113590      A       1        1       N     NaN         0
# 1  0113590      A       0        1       N     NaN         0
# 2  0113590      A       2        1       N     NaN         0
# 3  0115282      A       1        1       N     NaN         0
# 4  0115283      A       1        1       N     NaN         0
# 5  0115284      A       1        1       N     NaN         0
# 6  0115285      A       1        1       N     NaN         0
# 7  0115286      A       1        1       N     NaN         0
# 8  0115314      A       1        1       N     NaN         0
# 9  0115315      A       1        1       N     NaN         0
#
#                event_id            lchg_time            rcre_time  ...  \
# 0  0113590/000000000001  2008-08-27T16:19:02  2008-08-27T15:35:06  ...
# 1  0113590/000000000001  2008-09-09T18:08:56  2008-09-09T18:08:56  ...
# 2  0113590/000000000003  2008-09-09T18:55:16  2008-09-09T18:54:15  ...
# ...

# %%
print(df_drwng_pow_hist.shape)
print(df_result.shape)
# Out:
# (1881, 28)
# (1881, 35)

# %%
df_drwng_pow_hist['acid']=df_result['acid_t']
df_drwng_pow_hist.head()
# Out:
#          acid status  ts_cnt  bank_id del_flg remarks  dacc_lim  \
# 0  AC88861241      A       1        1       N     NaN         0
# 1  AC88861241      A       0        1       N     NaN         0
# 2  AC88861241      A       2        1       N     NaN         0
# 3  AC14042152      A       1        1       N     NaN         0
# 4  AC62240947      A       1        1       N     NaN         0
#
#                event_id            lchg_time            rcre_time  ...  \
# 0  0113590/000000000001  2008-08-27T16:19:02  2008-08-27T15:35:06  ...
# 1  0113590/000000000001  2008-09-09T18:08:56  2008-09-09T18:08:56  ...
# 2  0113590/000000000003  2008-09-09T18:55:16  2008-09-09T18:54:15  ...
# 3  0115282/000000000001  2008-09-10T14:28:40  2008-09-10T13:18:37  ...
# 4  0115283/000000000001  2008-09-10T14:29:58  2008-09-10T13:21:45  ...
#
#   lchg_user_id rcre_user_id dacc_lim_pcnt  dafa_lim_pcnt  tot_mod_times  \
# 0       SOPHYP       LAXMIS             0              0              0
# ...

# %%
df_drwng_pow_hist.to_csv("drwng_power_hist_tbl_masked.csv",index=False)
