# %%
import pandas as pd
df_acc_lien= pd.read_excel("account_lien_table.xlsx")
# df_acc_lien = df_acc_lien.drop(['_airbyte_ab_id', '_airbyte_emitted_at',"source_file_path","_airbyte_additional_properties"], axis=1)

df_acc_lien.head()
# Out:
#         acid      b2k_id sol_id  ts_cnt  bank_id del_flg user_id b2k_type  \
# 0  225746205  2210369522     22       0        1       N     NaN    LOANS
# 1  225746205   225758079     22       1        1       N     NaN    LOANS
# 2  225746205   227610563     22       1        1       N     NaN    LOANS
# 3  305912663   305913285     30       0        1       N     NaN    LOANS
# 4  549603190   309658898     54       0        1       N     NaN    LOANS
#
#    lien_amt            lchg_time  ... entity_cre_flg  \
# 0   7029.86  2024-08-01T22:50:41  ...              Y
# 1  19070.29  2024-08-01T22:51:15  ...              Y
# 2  41658.78  2024-08-01T22:51:17  ...              Y
# 3  22236.93  2024-08-01T23:03:27  ...              Y
# 4  10717.59  2024-08-01T23:03:28  ...              Y
#
#               lien_start_date  future_ulien_amt lien_expiry_date  \
# 0  2024-08-01T00:00:00.000000                 0              NaN
# 1  2024-08-01T00:00:00.000000                 0              NaN
# ...

# %%
df_gam=pd.read_csv("../general_acct_mast_table/general_acct_mast_table_masked.csv")
df_gam.head()
# Out:
#          acid      acid_t     cif_id           foracid           foracid_t  \
# 0   Q39620558  AC83477802  R02944296  2635752944296001  FA3683176010178129
# 1  Y110180600  AC28966287  O99520992  3414659520992004  FA9480299565595898
# 2   O93531058  AC98636744  O99520992  O987952099252401  FA7106544699531866
# 3    32559774  AC72858901  R32157797  3241157797524004  FA1631713350235916
# 4   889280082  AC73874192  R09092002  0884459092002067  FA2641279335334283
#
#        acct_num                   acct_name  \
# 0  831760101781     Humacanta Prasad Pandey
# 1  802995655958       Sriti Saraswati Limbu
# 2   65446995318       Sriti Saraswati Limbu
# 3  317133502359  PALPA HEALTHCARE PVT. LTD.
# 4  412793353342                         NaN
#
#                                   hashed_no        phone_num  \
# 0  C1426B129652A7DB20182EAE18980F1B26D3B17E       9829243528
# 1  26B23D96EE13CDC789D531D4CF5839AD1EF73B75              NaN
# ...

# %%
df_result = pd.merge(df_acc_lien, df_gam, how='left', on='acid',suffixes=('_p', '_a'))
df_result.head(80)
# Out:
#          acid       b2k_id sol_id_p  ts_cnt_p  bank_id_p del_flg_p user_id  \
# 0   225746205   2210369522       22         0          1         N     NaN
# 1   225746205    225758079       22         1          1         N     NaN
# 2   225746205    227610563       22         1          1         N     NaN
# 3   305912663    305913285       30         0          1         N     NaN
# 4   549603190    309658898       54         0          1         N     NaN
# ..        ...          ...      ...       ...        ...       ...     ...
# 60  F85795678  CASBA/SWMFI       F8         0          1         N     NaN
# 61  394192932    DC1962170       00         0          1         N  SS3851
# 62  D06224981     DC550005       D0         3          1         N  RS6759
# 63  Q39620558  CASBA/SWMFI       Q3         0          1         N     NaN
# 64  153396015   1510412040       15         1          1         N     NaN
#
# ...

# %%
df_acc_lien['acid']=df_result['acid_t']
df_acc_lien.head()
# Out:
#          acid      b2k_id sol_id  ts_cnt  bank_id del_flg user_id b2k_type  \
# 0  AC92720974  2210369522     22       0        1       N     NaN    LOANS
# 1  AC92720974   225758079     22       1        1       N     NaN    LOANS
# 2  AC92720974   227610563     22       1        1       N     NaN    LOANS
# 3  AC76635079   305913285     30       0        1       N     NaN    LOANS
# 4  AC54504657   309658898     54       0        1       N     NaN    LOANS
#
#    lien_amt            lchg_time  ... entity_cre_flg  \
# 0   7029.86  2024-08-01T22:50:41  ...              Y
# 1  19070.29  2024-08-01T22:51:15  ...              Y
# 2  41658.78  2024-08-01T22:51:17  ...              Y
# 3  22236.93  2024-08-01T23:03:27  ...              Y
# 4  10717.59  2024-08-01T23:03:28  ...              Y
#
#               lien_start_date  future_ulien_amt lien_expiry_date  \
# 0  2024-08-01T00:00:00.000000                 0              NaN
# ...

# %%
print(df_result.shape)
print(df_acc_lien.shape)
print(df_gam.shape)
# Out:
# (65, 216)
# (65, 27)
# (4087, 190)

# %%
df_acc_lien.to_csv("account_lien_table_masked.csv",index=False)
