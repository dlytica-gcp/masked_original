# %%
import pandas as pd
df_hist_tran_dtl= pd.read_excel("hist_tran_dtl_table.xlsx")
df_hist_tran_dtl.head()
# Out:
#                tran_date    tran_id  part_tran_srl_num del_flg tran_type  \
# 0  2024-02-04 00:00:00.0    DC30557                  1       N         T
# 1  2023-08-01 00:00:00.0  S36704191                  1       N         T
# 2  2024-06-15 00:00:00.0  S95260619                  1       N         T
# 3  2023-08-02 00:00:00.0    DC31505                  2       N         T
# 4  2024-04-15 00:00:00.0  S64156746                425       N         T
#
#   tran_sub_type part_tran_type  gl_sub_head_code      acid  \
# 0            CI              D             45105  01238069
# 1            SI              D              4503  02264368
# 2            SI              D              4503  02264368
# 3            CI              C              4200  02559106
# 4            BI              D              4200  02559106
#
#               value_date  ...  tran_free_code1 tran_free_code2 pstd_srl_num  \
# 0  2024-02-04 00:00:00.0  ...              NaN             NaN            0
# ...

# %%
df_gam=pd.read_csv("../general_acct_mast_table/acid_foracid_masked.csv")
df_gam.head()
# Out:
#          acid      acid_t         cif_id           foracid  \
# 0   Q39620558  AC10370877  DLNIND1406504  2635752944296001
# 1  Y110180600  AC41672289  DLNIND4211643  3414659520992004
# 2   O93531058  AC73584145  DLNIND4211643  O987952099252401
# 3    32559774  AC12345718  DLNLEG9334212  3241157797524004
# 4   889280082  AC47235600  DLNLEG6576494  0884459092002067
#
#             foracid_t           pan      acct_num                   acct_name
# 0  FA9627239668220084  PAN668645879  272396682200       Humacanta Bipin Thapa
# 1  FA3302344775994664  PAN697945863   23447759946          Sriti Kumari Thapa
# 2  FA5553585851915269  PAN697945863  535858519152          Sriti Kumari Thapa
# 3  FA2582732553674743  PAN353089449  827325536747  PALPA HEALTHCARE PVT. LTD.
# 4  FA7171012596574289  PAN813377590  710125965742                         NaN

# %%
df_result = pd.merge(df_hist_tran_dtl, df_gam, how='left', on='acid',suffixes=('_p', '_a'))
df_result.head(10)
# Out:
#                tran_date    tran_id  part_tran_srl_num del_flg tran_type  \
# 0  2024-02-04 00:00:00.0    DC30557                  1       N         T
# 1  2023-08-01 00:00:00.0  S36704191                  1       N         T
# 2  2024-06-15 00:00:00.0  S95260619                  1       N         T
# 3  2023-08-02 00:00:00.0    DC31505                  2       N         T
# 4  2024-04-15 00:00:00.0  S64156746                425       N         T
# 5  2023-08-01 00:00:00.0  S36704191                  2       N         T
# 6  2024-06-15 00:00:00.0  S95260619                  2       N         T
# 7  2023-09-01 00:00:00.0  S51361528               1151       N         T
# 8  2024-02-01 00:00:00.0    DC48610                  2       N         T
# 9  2024-03-01 00:00:00.0    DC35465                  2       N         T
#
#   tran_sub_type part_tran_type  gl_sub_head_code       acid  \
# 0            CI              D             45105   01238069
# ...

# %%
print(df_hist_tran_dtl.shape)
print(df_result.shape)
# Out:
# (3017, 99)
# (3017, 106)

# %%
df_hist_tran_dtl['acid']=df_result['acid_t'].values
df_hist_tran_dtl.head()
# Out:
#                tran_date    tran_id  part_tran_srl_num del_flg tran_type  \
# 0  2024-02-04 00:00:00.0    DC30557                  1       N         T
# 1  2023-08-01 00:00:00.0  S36704191                  1       N         T
# 2  2024-06-15 00:00:00.0  S95260619                  1       N         T
# 3  2023-08-02 00:00:00.0    DC31505                  2       N         T
# 4  2024-04-15 00:00:00.0  S64156746                425       N         T
#
#   tran_sub_type part_tran_type  gl_sub_head_code        acid  \
# 0            CI              D             45105  AC90312813
# 1            SI              D              4503  AC50755170
# 2            SI              D              4503  AC50755170
# 3            CI              C              4200  AC38803203
# 4            BI              D              4200  AC38803203
#
#               value_date  ...  tran_free_code1 tran_free_code2 pstd_srl_num  \
# 0  2024-02-04 00:00:00.0  ...              NaN             NaN            0
# ...

# %%
df_hist_tran_dtl.to_csv("hist_tran_dtl_table_masked.csv",index=False)
