# %%
import pandas as pd
df_general_margin_hist= pd.read_excel("general_margin_history.xlsx")
df_general_margin_hist.head()
# Out:
#       b2kid  ts_cnt  bank_id             remarks  srl_num  event_amt  \
# 0   DC09468       1        1           LC MARGIN        1     706000
# 1   DC09469       1        1           LC MARGIN        1    1265000
# 2   DC09468       1        1  LC MARGIN RELEASED        2     706000
# 3   DC09469       1        1  LC MARGIN RELEASED        2    1265000
# 4  DC101348       1        1           LC MARGIN        1     121000
#
#              lchg_time  oper_acid            rcre_time b2kid_type  ...  \
# 0  2009-01-25T18:41:46     424553  2009-01-25T18:39:39      DOCCR  ...
# 1  2009-01-25T18:46:40     424553  2009-01-25T18:45:14      DOCCR  ...
# 2  2009-02-17T18:22:43     424553  2009-02-17T17:03:27      DOCCR  ...
# 3  2009-02-17T19:19:29     424553  2009-02-17T17:02:45      DOCCR  ...
# 4  2010-06-23T12:23:27     424553  2010-06-23T12:17:09      DOCCR  ...
#
#   entity_cre_flg  margin_srl_num margin_tran_id  link_b2kid_type  \
# ...

# %%
df_general_margin_hist.to_csv("general_margin_history_masked.csv",index=False)
