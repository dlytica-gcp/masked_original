# %%
import pandas as pd
df_gen_acct_class= pd.read_excel("gen_acct_class_table.xlsx")
df_gen_acct_class.head()
# Out:
#         acid pd_flg  ts_cnt  bank_id  ref_num  apy_pcnt  dpd_cntr ecs_flag  \
# 0  021795331      N       0        1      NaN       0.0         0        N
# 1  231814814      N       0        1      NaN       0.0         0        N
# 2  021818301      N       0        1      NaN       0.0         0        N
# 3  231823082      N       0        1      NaN       0.0         0        N
# 4   22695209      N       3        1      NaN       0.0         0      NaN
#
#    ias_code            lchg_time  ... penal_prod_mthd_flg  \
# 0       NaN  2017-06-15T12:29:45  ...                 NaN
# 1       NaN  2017-06-20T12:44:25  ...                 NaN
# 2       NaN  2017-06-25T12:34:02  ...                 NaN
# 3       NaN  2017-07-03T11:01:17  ...                 NaN
# 4       NaN  2017-07-03T16:40:04  ...                 NaN
#
#    penal_rate_mthd_flg used_for_net_off_flg borrower_category_code  \
# 0                  NaN                  NaN                    NaN
# ...

# %%
df_gam=pd.read_csv("../general_acct_mast_table/general_acct_mast_table_masked.csv")
df_gam.head()
# Out:
#          acid      acid_t     cif_id           foracid           foracid_t  \
# 0   Q39620558  AC83477802  R02944296  2635752944296001  FA3683176010178129
# 1  Y110180600  AC28966287  O99520992  3414659520992004  FA9480299565595898
# 2   O93531058  AC98636744  O99520992  O987952099252401  FA7106544699531866
# 3    32559774  AC72858901  R32157797  3241157797524004  FA1631713350235916
# 4   889280082  AC73874192  R09092002  0884459092002067  FA2641279335334283
#
#        acct_num                   acct_name  \
# 0  831760101781     Humacanta Prasad Pandey
# 1  802995655958       Sriti Saraswati Limbu
# 2   65446995318       Sriti Saraswati Limbu
# 3  317133502359  PALPA HEALTHCARE PVT. LTD.
# 4  412793353342                         NaN
#
#                                   hashed_no        phone_num  \
# 0  C1426B129652A7DB20182EAE18980F1B26D3B17E       9829243528
# 1  26B23D96EE13CDC789D531D4CF5839AD1EF73B75              NaN
# ...

# %%
df_result = pd.merge(df_gen_acct_class, df_gam, how='left', on='acid',suffixes=('_p', '_a'))
df_result.head(10)
# Out:
#         acid pd_flg  ts_cnt_p  bank_id_p  ref_num  apy_pcnt  dpd_cntr  \
# 0  021795331      N         0          1      NaN       0.0         0
# 1  231814814      N         0          1      NaN       0.0         0
# 2  021818301      N         0          1      NaN       0.0         0
# 3  231823082      N         0          1      NaN       0.0         0
# 4   22695209      N         3          1      NaN       0.0         0
# 5  091823841      N         1          1      NaN       0.0         0
# 6  091824356      N         0          1      NaN       0.0         0
# 7  281826602      N         0          1      NaN       0.0         0
# 8  991839797      N         1          1      NaN       0.0         0
# 9  021846742      N         0          1      NaN       0.0         0
#
#   ecs_flag  ias_code          lchg_time_p  ... acct_cls_advice_printed  \
# 0        N       NaN  2017-06-15T12:29:45  ...                     NaN
# ...

# %%
print(df_gen_acct_class.shape)
print(df_result.shape)
# Out:
# (4061, 97)
# (4061, 286)

# %%
df_gen_acct_class['acid']=df_result['acid_t'].values
df_gen_acct_class.head()
# Out:
#          acid pd_flg  ts_cnt  bank_id  ref_num  apy_pcnt  dpd_cntr ecs_flag  \
# 0  AC76866944      N       0        1      NaN       0.0         0        N
# 1  AC62077813      N       0        1      NaN       0.0         0        N
# 2  AC57981284      N       0        1      NaN       0.0         0        N
# 3  AC92770785      N       0        1      NaN       0.0         0        N
# 4  AC61785205      N       3        1      NaN       0.0         0      NaN
#
#    ias_code            lchg_time  ... penal_prod_mthd_flg  \
# 0       NaN  2017-06-15T12:29:45  ...                 NaN
# 1       NaN  2017-06-20T12:44:25  ...                 NaN
# 2       NaN  2017-06-25T12:34:02  ...                 NaN
# 3       NaN  2017-07-03T11:01:17  ...                 NaN
# 4       NaN  2017-07-03T16:40:04  ...                 NaN
#
#    penal_rate_mthd_flg used_for_net_off_flg borrower_category_code  \
# 0                  NaN                  NaN                    NaN
# ...

# %%
df_gen_acct_class.to_csv("gen_acct_class_table_masked.csv",index=False)
