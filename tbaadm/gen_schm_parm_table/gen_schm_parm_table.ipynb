# %%
import pandas as pd
df_gem_schm_parm= pd.read_excel("gen_schm_parm_table.xlsx")
df_gem_schm_parm.head()
# Out:
#   SET_ID  TS_CNT  BANK_ID DEL_FLG EEFC_FLG                    END_DATE  \
# 0    ALL     494        1       N        N  2099-12-31T00:00:00.000000
# 1    ALL       7        1       N        N  2099-12-31T00:00:00.000000
# 2    ALL      11        1       N        N  2099-12-31T00:00:00.000000
# 3    ALL       8        1       N        N  2099-12-31T00:00:00.000000
# 4    ALL       2        1       N        N  2099-12-31T00:00:00.000000
#
#   FCNR_FLG            LCHG_TIME                   RCRE_TIME  RULE_CODE  ...  \
# 0        N  2024-08-08T12:21:09  2014-06-05T14:12:00.000000        NaN  ...
# 1        N  2024-08-08T18:16:41         2014-01-22T12:38:52        NaN  ...
# 2        N  2024-08-14T15:25:45         2016-10-04T12:40:29        NaN  ...
# 3        N  2024-08-14T15:26:01         2021-03-26T15:36:51        NaN  ...
# 4        N  2024-08-15T17:40:46         2024-08-13T14:30:39        NaN  ...
#
#   ISO_USER_TOD_GRNT_EXCP_CODE ISTISNA_WORK_PROGRESS_BACID  \
# ...

# %%
df_gem_schm_parm.to_csv("gen_schm_parm_table_masked.csv",index=False)
