# %%
import pandas as pd
df_interest_detail= pd.read_excel("interest_details_table.xlsx")
df_interest_detail.head()
# Out:
#    entity_id entity_type interest_ind interest_type  serial_num  \
# 0  V88046198       ACCNT            C             N         620
# 1  V88046198       ACCNT            C             N         624
# 2  V88046198       ACCNT            C             N         625
# 3  V88046198       ACCNT            C             N         626
# 4  V88046198       ACCNT            C             N         627
#
#   entity_cre_flg    product  product_for_int_rate  diff_product  \
# 0              Y  154440.65             154440.65             0
# 1              Y  156762.23             156762.23             0
# 2              Y  156762.23             156762.23             0
# 3              Y  156762.23             156762.23             0
# 4              Y  156762.23             156762.23             0
#
#               start_date  ... last_comp_amount_cr int_appl_flg_cr  \
# 0  2024-04-11 00:00:00.0  ...                   0
# 1  2024-04-15 00:00:00.0  ...                   0
# ...

# %%
df_gam=pd.read_csv("../general_acct_mast_table/general_acct_mast_table_masked.csv")
df_gam.head()
# Out:
#          acid      acid_t     cif_id           foracid           foracid_t  \
# 0   Q39620558  AC83477802  R02944296  2635752944296001  FA3683176010178129
# 1  Y110180600  AC28966287  O99520992  3414659520992004  FA9480299565595898
# 2   O93531058  AC98636744  O99520992  O987952099252401  FA7106544699531866
# 3    32559774  AC72858901  R32157797  3241157797524004  FA1631713350235916
# 4   889280082  AC73874192  R09092002  0884459092002067  FA2641279335334283
#
#        acct_num                   acct_name  \
# 0  831760101781     Humacanta Prasad Pandey
# 1  802995655958       Sriti Saraswati Limbu
# 2   65446995318       Sriti Saraswati Limbu
# 3  317133502359  PALPA HEALTHCARE PVT. LTD.
# 4  412793353342                         NaN
#
#                                   hashed_no        phone_num  \
# 0  C1426B129652A7DB20182EAE18980F1B26D3B17E       9829243528
# 1  26B23D96EE13CDC789D531D4CF5839AD1EF73B75              NaN
# ...

# %%
df_result = pd.merge(left_on='entity_id', right_on='acid',left=df_interest_detail,right=df_gam,how='left',suffixes=('_p', '_a'))
df_result.head(5)
# Out:
#    entity_id entity_type interest_ind interest_type  serial_num  \
# 0  V88046198       ACCNT            C             N         620
# 1  V88046198       ACCNT            C             N         624
# 2  V88046198       ACCNT            C             N         625
# 3  V88046198       ACCNT            C             N         626
# 4  V88046198       ACCNT            C             N         627
#
#   entity_cre_flg_p    product  product_for_int_rate  diff_product  \
# 0                Y  154440.65             154440.65             0
# 1                Y  156762.23             156762.23             0
# 2                Y  156762.23             156762.23             0
# 3                Y  156762.23             156762.23             0
# 4                Y  156762.23             156762.23             0
#
#               start_date  ... acct_cls_advice_printed acct_cls_chrg_pend_verf  \
# 0  2024-04-11 00:00:00.0  ...                     NaN                     NaN
# ...

# %%
print(df_interest_detail.shape)
print(df_result.shape)
# Out:
# (8297, 46)
# (8297, 236)

# %%
df_interest_detail['entity_id']=df_result['acid_t'].values
df_interest_detail.head()
# Out:
#     entity_id entity_type interest_ind interest_type  serial_num  \
# 0  AC76354668       ACCNT            C             N         620
# 1  AC76354668       ACCNT            C             N         624
# 2  AC76354668       ACCNT            C             N         625
# 3  AC76354668       ACCNT            C             N         626
# 4  AC76354668       ACCNT            C             N         627
#
#   entity_cre_flg    product  product_for_int_rate  diff_product  \
# 0              Y  154440.65             154440.65             0
# 1              Y  156762.23             156762.23             0
# 2              Y  156762.23             156762.23             0
# 3              Y  156762.23             156762.23             0
# 4              Y  156762.23             156762.23             0
#
#               start_date  ... last_comp_amount_cr int_appl_flg_cr  \
# 0  2024-04-11 00:00:00.0  ...                   0
# 1  2024-04-15 00:00:00.0  ...                   0
# ...

# %%
df_interest_detail.to_csv("interest_details_table_masked.csv",index=False)
