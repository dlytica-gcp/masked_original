# %%
import pandas as pd
df_interest_detail= pd.read_excel("interest_details_table.xlsx")
df_interest_detail.head()
# Out:
#    entity_id entity_type interest_ind interest_type  serial_num  \
# 0  V88046198       ACCNT            C             N         620
# 1  V88046198       ACCNT            C             N         624
# 2  V88046198       ACCNT            C             N         625
# 3  V88046198       ACCNT            C             N         626
# 4  V88046198       ACCNT            C             N         627
#
#   entity_cre_flg    product  product_for_int_rate  diff_product  \
# 0              Y  154440.65             154440.65             0
# 1              Y  156762.23             156762.23             0
# 2              Y  156762.23             156762.23             0
# 3              Y  156762.23             156762.23             0
# 4              Y  156762.23             156762.23             0
#
#               start_date  ... last_comp_amount_cr int_appl_flg_cr  \
# 0  2024-04-11 00:00:00.0  ...                   0
# 1  2024-04-15 00:00:00.0  ...                   0
# 2  2024-04-16 00:00:00.0  ...                   0
# 3  2024-04-17 00:00:00.0  ...                   0
# 4  2024-04-18 00:00:00.0  ...                   0
#
#    wtax_amount_scope_flg itax_for_floor_limit_flg  wtax_pcnt  \
# 0                      P                        N          6
# 1                      P                        N          6
# 2                      P                        N          6
# 3                      P                        N          6
# 4                      P                        N          6
#
#    wtax_floor_limit  last_comp_tax  tax_amount wtax_for_cr_comp  \
# 0                 0      81.533221    2.824027                N
# 1                 0       8.493304    2.844043                N
# 2                 0      11.338206    2.844902                N
# 3                 0      14.183968    2.845762                N
# 4                 0      17.030590    2.846622                N
#
#                updated_at
# 0 2024-07-30 09:10:10.576
# 1 2024-07-30 09:10:10.576
# 2 2024-07-30 09:10:10.576
# 3 2024-07-30 09:10:10.576
# 4 2024-07-30 09:10:10.576
#
# [5 rows x 46 columns]

# %%
df_gam=pd.read_csv("../general_acct_mast_table/acid_foracid_masked.csv")
df_gam.head()
# Out:
#          acid      acid_t         cif_id           foracid  \
# 0   Q39620558  AC10370877  DLNIND1406504  2635752944296001
# 1  Y110180600  AC41672289  DLNIND4211643  3414659520992004
# 2   O93531058  AC73584145  DLNIND4211643  O987952099252401
# 3    32559774  AC12345718  DLNLEG9334212  3241157797524004
# 4   889280082  AC47235600  DLNLEG6576494  0884459092002067
#
#             foracid_t           pan      acct_num                   acct_name
# 0  FA9627239668220084  PAN668645879  272396682200       Humacanta Bipin Thapa
# 1  FA3302344775994664  PAN697945863   23447759946          Sriti Kumari Thapa
# 2  FA5553585851915269  PAN697945863  535858519152          Sriti Kumari Thapa
# 3  FA2582732553674743  PAN353089449  827325536747  PALPA HEALTHCARE PVT. LTD.
# 4  FA7171012596574289  PAN813377590  710125965742                         NaN

# %%
df_result = pd.merge(left_on='entity_id', right_on='acid',left=df_interest_detail,right=df_gam,how='left',suffixes=('_p', '_a'))
df_result.head(5)
# Out:
#    entity_id entity_type interest_ind interest_type  serial_num  \
# 0  V88046198       ACCNT            C             N         620
# 1  V88046198       ACCNT            C             N         624
# 2  V88046198       ACCNT            C             N         625
# 3  V88046198       ACCNT            C             N         626
# 4  V88046198       ACCNT            C             N         627
#
#   entity_cre_flg    product  product_for_int_rate  diff_product  \
# 0              Y  154440.65             154440.65             0
# 1              Y  156762.23             156762.23             0
# 2              Y  156762.23             156762.23             0
# 3              Y  156762.23             156762.23             0
# 4              Y  156762.23             156762.23             0
#
#               start_date  ... wtax_for_cr_comp              updated_at  \
# 0  2024-04-11 00:00:00.0  ...                N 2024-07-30 09:10:10.576
# 1  2024-04-15 00:00:00.0  ...                N 2024-07-30 09:10:10.576
# 2  2024-04-16 00:00:00.0  ...                N 2024-07-30 09:10:10.576
# 3  2024-04-17 00:00:00.0  ...                N 2024-07-30 09:10:10.576
# 4  2024-04-18 00:00:00.0  ...                N 2024-07-30 09:10:10.576
#
#         acid      acid_t         cif_id           foracid           foracid_t  \
# 0  V88046198  AC43416524  DLNIND3257367  3184652275983002  FA1646220598508770
# 1  V88046198  AC43416524  DLNIND3257367  3184652275983002  FA1646220598508770
# 2  V88046198  AC43416524  DLNIND3257367  3184652275983002  FA1646220598508770
# 3  V88046198  AC43416524  DLNIND3257367  3184652275983002  FA1646220598508770
# 4  V88046198  AC43416524  DLNIND3257367  3184652275983002  FA1646220598508770
#
#             pan      acct_num            acct_name
# 0  PAN727567807  462205985087  Aavaas Ram Adhikari
# 1  PAN727567807  462205985087  Aavaas Ram Adhikari
# 2  PAN727567807  462205985087  Aavaas Ram Adhikari
# 3  PAN727567807  462205985087  Aavaas Ram Adhikari
# 4  PAN727567807  462205985087  Aavaas Ram Adhikari
#
# [5 rows x 54 columns]

# %%
print(df_interest_detail.shape)
print(df_result.shape)
# Out:
# (8297, 46)
# (8297, 54)

# %%
df_interest_detail['entity_id']=df_result['acid_t'].values
df_interest_detail.head()
# Out:
#     entity_id entity_type interest_ind interest_type  serial_num  \
# 0  AC43416524       ACCNT            C             N         620
# 1  AC43416524       ACCNT            C             N         624
# 2  AC43416524       ACCNT            C             N         625
# 3  AC43416524       ACCNT            C             N         626
# 4  AC43416524       ACCNT            C             N         627
#
#   entity_cre_flg    product  product_for_int_rate  diff_product  \
# 0              Y  154440.65             154440.65             0
# 1              Y  156762.23             156762.23             0
# 2              Y  156762.23             156762.23             0
# 3              Y  156762.23             156762.23             0
# 4              Y  156762.23             156762.23             0
#
#               start_date  ... last_comp_amount_cr int_appl_flg_cr  \
# 0  2024-04-11 00:00:00.0  ...                   0
# 1  2024-04-15 00:00:00.0  ...                   0
# 2  2024-04-16 00:00:00.0  ...                   0
# 3  2024-04-17 00:00:00.0  ...                   0
# 4  2024-04-18 00:00:00.0  ...                   0
#
#    wtax_amount_scope_flg itax_for_floor_limit_flg  wtax_pcnt  \
# 0                      P                        N          6
# 1                      P                        N          6
# 2                      P                        N          6
# 3                      P                        N          6
# 4                      P                        N          6
#
#    wtax_floor_limit  last_comp_tax  tax_amount wtax_for_cr_comp  \
# 0                 0      81.533221    2.824027                N
# 1                 0       8.493304    2.844043                N
# 2                 0      11.338206    2.844902                N
# 3                 0      14.183968    2.845762                N
# 4                 0      17.030590    2.846622                N
#
#                updated_at
# 0 2024-07-30 09:10:10.576
# 1 2024-07-30 09:10:10.576
# 2 2024-07-30 09:10:10.576
# 3 2024-07-30 09:10:10.576
# 4 2024-07-30 09:10:10.576
#
# [5 rows x 46 columns]

# %%
df_interest_detail.to_csv("interest_details_table_masked.csv",index=False)
