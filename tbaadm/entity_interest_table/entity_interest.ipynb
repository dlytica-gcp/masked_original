# %%
import pandas as pd
df_entity_interest= pd.read_excel("entity_interest_table.xlsx")
df_entity_interest.head()
# Out:
#    ts_cnt  bank_id  entity_id            lchg_time            rcre_time  \
# 0     190        1  R85272464  2020-06-03T00:26:19  2020-03-03T11:19:56
# 1     190        1  R85274118  2020-06-03T00:26:19  2020-03-03T17:31:54
# 2     190        1  285285319  2020-06-09T23:35:49  2020-03-10T14:51:43
# 3     190        1  R85286857  2020-06-10T23:27:59  2020-03-11T13:36:02
# 4     190        1  285305444  2020-06-17T21:23:18  2020-03-18T11:47:07
#
#   crncy_code diff_exists entity_type int_tbl_code lchg_user_id  ...  \
# 0        NPR         NaN       ACCNT          NaN     FINADMIN  ...
# 1        NPR         NaN       ACCNT          NaN     FINADMIN  ...
# 2        NPR         NaN       ACCNT          NaN     FINADMIN  ...
# 3        NPR         NaN       ACCNT          NaN     FINADMIN  ...
# 4        NPR         NaN       ACCNT          NaN     FINADMIN  ...
#
#   penalint_interest_amount_dr  penalprnc_accrued_amount_dr  \
# 0                           0                            0
# ...

# %%
df_gam=pd.read_csv("../general_acct_mast_table/general_acct_mast_table_masked.csv")
df_gam.head()
# Out:
#          acid      acid_t     cif_id           foracid           foracid_t  \
# 0   Q39620558  AC83477802  R02944296  2635752944296001  FA3683176010178129
# 1  Y110180600  AC28966287  O99520992  3414659520992004  FA9480299565595898
# 2   O93531058  AC98636744  O99520992  O987952099252401  FA7106544699531866
# 3    32559774  AC72858901  R32157797  3241157797524004  FA1631713350235916
# 4   889280082  AC73874192  R09092002  0884459092002067  FA2641279335334283
#
#        acct_num                   acct_name  \
# 0  831760101781     Humacanta Prasad Pandey
# 1  802995655958       Sriti Saraswati Limbu
# 2   65446995318       Sriti Saraswati Limbu
# 3  317133502359  PALPA HEALTHCARE PVT. LTD.
# 4  412793353342                         NaN
#
#                                   hashed_no        phone_num  \
# 0  C1426B129652A7DB20182EAE18980F1B26D3B17E       9829243528
# 1  26B23D96EE13CDC789D531D4CF5839AD1EF73B75              NaN
# ...

# %%
df_result = pd.merge(left_on='entity_id', right_on='acid',left=df_entity_interest,right=df_gam,how='left',suffixes=('_p', '_a'))
df_result.head(5)
# Out:
#    ts_cnt_p  bank_id_p  entity_id          lchg_time_p          rcre_time_p  \
# 0       190          1  R85272464  2020-06-03T00:26:19  2020-03-03T11:19:56
# 1       190          1  R85274118  2020-06-03T00:26:19  2020-03-03T17:31:54
# 2       190          1  285285319  2020-06-09T23:35:49  2020-03-10T14:51:43
# 3       190          1  R85286857  2020-06-10T23:27:59  2020-03-11T13:36:02
# 4       190          1  285305444  2020-06-17T21:23:18  2020-03-18T11:47:07
#
#   crncy_code_p diff_exists entity_type int_tbl_code lchg_user_id_p  ...  \
# 0          NPR         NaN       ACCNT          NaN       FINADMIN  ...
# 1          NPR         NaN       ACCNT          NaN       FINADMIN  ...
# 2          NPR         NaN       ACCNT          NaN       FINADMIN  ...
# 3          NPR         NaN       ACCNT          NaN       FINADMIN  ...
# 4          NPR         NaN       ACCNT          NaN       FINADMIN  ...
#
# ...

# %%
print(df_entity_interest.shape)
print(df_result.shape)
# Out:
# (4418, 170)
# (4418, 360)

# %%
df_entity_interest['entity_id']=df_result['acid_t'].values
df_entity_interest.head()
# Out:
#    ts_cnt  bank_id  entity_id            lchg_time            rcre_time  \
# 0     190        1  R85272464  2020-06-03T00:26:19  2020-03-03T11:19:56
# 1     190        1  R85274118  2020-06-03T00:26:19  2020-03-03T17:31:54
# 2     190        1  285285319  2020-06-09T23:35:49  2020-03-10T14:51:43
# 3     190        1  R85286857  2020-06-10T23:27:59  2020-03-11T13:36:02
# 4     190        1  285305444  2020-06-17T21:23:18  2020-03-18T11:47:07
#
#   crncy_code diff_exists entity_type int_tbl_code lchg_user_id  ...  \
# 0        NPR         NaN       ACCNT          NaN     FINADMIN  ...
# 1        NPR         NaN       ACCNT          NaN     FINADMIN  ...
# 2        NPR         NaN       ACCNT          NaN     FINADMIN  ...
# 3        NPR         NaN       ACCNT          NaN     FINADMIN  ...
# 4        NPR         NaN       ACCNT          NaN     FINADMIN  ...
#
#   penalprnc_accrued_amount_dr  penalprnc_interest_amount_dr  \
# ...

# %%
df_entity_interest.to_csv("entity_interest_table_masked.csv",index=False)
