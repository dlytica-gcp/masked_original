# %%
import pandas as pd
bg_master_table= pd.read_excel("bg_master_table.xlsx")
# bg_master_table = bg_master_table.drop(['_airbyte_ab_id', '_airbyte_emitted_at',"source_file_path","_airbyte_additional_properties"], axis=1)

bg_master_table.head()
# Out:
#    rate     bg_amt sol_id  ts_cnt  bank_id  bene_br bg_type  br_code  \
# 0     1   200000.0     01       3        1      NaN   BOABB      NaN
# 1     1  5000000.0     01       7        1      NaN   BOAAG      NaN
# 2     1   200000.0     01       3        1      NaN   BOABB      NaN
# 3     1   125000.0     01       3        1      NaN   BOABB      NaN
# 4     1   125000.0     01       3        1      NaN   BOABB      NaN
#
#      cust_id bg_b2kid  ... probable_date_of_shpmnt auto_renew_freq_cal_base  \
# 0   01001079  DC09168  ...                     NaN                      NaN
# 1   01001079   DC0896  ...                     NaN                      NaN
# 2   01001079  DC09169  ...                     NaN                      NaN
# 3   01001079  DC10294  ...                     NaN                      NaN
# 4   01001079  DC10295  ...                     NaN                      NaN
#
#    auto_renew_freq_week_day  auto_renew_freq_week_num  \
# ...

# %%
bg_master_table.to_csv("bg_master_table_masked.csv",index=False)
