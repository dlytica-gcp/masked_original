# %%
import pandas as pd
df_terms=pd.read_excel("terms.xlsx")
df_terms.head()
# Out:
#    ter_code  ter_iden  ter_acc_code  ter_ban_code                ter_due_date  \
# 0  82674921       NaN       2368814             1  2023-04-09T00:00:00.000000
# 1  82770441       NaN       2368762             1  2023-04-09T00:00:00.000000
# 2  82771921       NaN       2368795             1  2023-04-09T00:00:00.000000
# 3  82772041       NaN       2368803             1  2023-04-09T00:00:00.000000
# 4  82772081       NaN       2368815             1  2023-04-09T00:00:00.000000
#
#    ter_mini_due  ter_clos_bala  ter_cred_limi  ter_cumu_paym  \
# 0      45327.07       45327.07          70000       45327.07
# 1       7448.41       12105.91          95000        7448.41
# 2       5511.38       49268.47          82000        5511.38
# 3       1399.77       13997.69         100000        1399.77
# 4      19677.00       19677.00         100000       19677.00
#
#                 ter_cycl_date  ... ter_unpa_numb          ter_last_cycl_date  \
# ...

# %%
df_terms.to_csv("terms_masked.csv",index=False)
