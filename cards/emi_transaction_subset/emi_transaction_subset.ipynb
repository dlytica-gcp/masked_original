# %%
import pandas as pd
df_emi_tran_sub=pd.read_excel("emi_transaction_subset.xlsx")
df_emi_tran_sub.head()
# Out:
#    etr_id  etr_code                                 etr_text etr_reason  \
# 0     NaN     34541  Migrated EMI From Old Switch 25-03-2023  Processed
# 1     NaN     34621  Migrated EMI From Old Switch 25-03-2023  Processed
# 2     NaN     36661  Migrated EMI From Old Switch 25-03-2023  Processed
# 3     NaN     36301  Migrated EMI From Old Switch 25-03-2023  Processed
# 4     NaN     27341  Migrated EMI From Old Switch 25-03-2023  Processed
#
#    etr_acc_code  etr_acc_numb  etr_ban_code  etr_car_code  etr_crt_code  \
# 0       2368814  524700013597             1       2127285           NaN
# 1       2368829  524700013646             1       2138061           NaN
# 2       2368762  524700014564             1       2122504           NaN
# 3       2368815  524700014324             1       2129000           NaN
# 4       2355341  100700000005             1       2105953           NaN
#
#    etr_cur_code  ... etr_holiday_period          etr_next_post_date  \
# ...

# %%
df_emi_tran_sub.to_csv("emi_transaction_subset_masked.csv",index=False)
