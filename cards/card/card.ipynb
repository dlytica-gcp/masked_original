# %%
import pandas as pd
import random
df_card=pd.read_excel("card.xlsx")
df_card.head()
# Out:
#   car_dob  car_uid  car_code  car_cvc2 car_gend  car_natu          car_numb  \
# 0     NaN      NaN    590314       NaN     Male       NaN  4235590007805459
# 1     NaN      NaN    627313       NaN     Male       NaN  4235590009725739
# 2     NaN      NaN    641547       NaN     Male       NaN  4235590009196568
# 3     NaN      NaN    657880       NaN     Male       NaN  4235590004467345
# 4     NaN      NaN    663940       NaN     Male       NaN  4235599990588527
#
#    car_phot  car_token car_trac1  ... car_rene_new_prep_date  \
# 0       NaN        NaN         Y  ...                    NaN
# 1       NaN        NaN         Y  ...                    NaN
# 2       NaN        NaN         Y  ...                    NaN
# 3       NaN        NaN         Y  ...                    NaN
# 4       NaN        NaN         Y  ...                    NaN
#
#    car_rene_old_expi_date  car_repl_new_card_numb  car_repl_new_effe_date  \
# ...

# %%
df_card['car_numb']=df_card['car_numb'].astype(str).apply(lambda x: '123456' +x[6:])

# %%
df_card.head()
# Out:
#   car_dob  car_uid  car_code  car_cvc2 car_gend  car_natu          car_numb  \
# 0     NaN      NaN    590314       NaN     Male       NaN  1234560007805459
# 1     NaN      NaN    627313       NaN     Male       NaN  1234560009725739
# 2     NaN      NaN    641547       NaN     Male       NaN  1234560009196568
# 3     NaN      NaN    657880       NaN     Male       NaN  1234560004467345
# 4     NaN      NaN    663940       NaN     Male       NaN  1234569990588527
#
#    car_phot  car_token car_trac1  ... car_rene_new_prep_date  \
# 0       NaN        NaN         Y  ...                    NaN
# 1       NaN        NaN         Y  ...                    NaN
# 2       NaN        NaN         Y  ...                    NaN
# 3       NaN        NaN         Y  ...                    NaN
# 4       NaN        NaN         Y  ...                    NaN
#
#    car_rene_old_expi_date  car_repl_new_card_numb  car_repl_new_effe_date  \
# ...

# %%
df_card.to
