# %%
import pandas as pd
df_emi_tran=pd.read_excel("emi_transaction.xlsx")
df_emi_tran.head()
# Out:
#    etr_id  etr_code                                 etr_text   etr_reason  \
# 0     NaN     60941                                      NaN  Not Matched
# 1     NaN     74201                                      NaN  Not Matched
# 2     NaN    115761                                      NaN  Not Matched
# 3     NaN    124981                                      NaN  Not Matched
# 4     NaN     32141  Migrated EMI From Old Switch 25-03-2023    Processed
#
#    etr_acc_code   etr_acc_numb  etr_ban_code  etr_car_code  etr_crt_code  \
# 0     2375158.0   524700013637             1     2131689.0           NaN
# 1     2384928.0   524700013699             1     2125095.0           NaN
# 2     2418623.0  7524000000387             1     2169243.0           NaN
# 3     2406382.0  7524000000209             1     2157222.0           NaN
# 4     2379921.0   524700011494             1     2124962.0           NaN
#
#    etr_cur_code  ... etr_holiday_period          etr_next_post_date  \
# ...

# %%
df_emi_tran.to_csv("emi_transaction_masked.csv",index=False)
