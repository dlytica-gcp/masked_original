# %%
import pandas as pd
df_c_loan_pen_int=pd.read_excel("c_loan_pen_int.xlsx")
df_c_loan_pen_int.head()
# Out:
#       acid del_flg due_flg   int_due    prn_due    product    tran_id  \
# 0  0118583       N       B  84341.86  390111.49  390111.49   S9514679
# 1  0118583       N       B  84341.86  390111.49  390111.49   S9526030
# 2  0118583       N       B  84341.86  390111.49  390111.49   S9535617
# 3  0118583       N       B  84341.86  390111.49  390111.49   S9546763
# 4  0118583       N       B  84341.86  390111.49  390111.49   S9558052
#
#    tran_amt trans_flg                   tran_date      loan_account  \
# 0     32.06         B  2015-01-01T00:00:00.000000  01EF001079NPR013
# 1     32.06         B  2015-01-02T00:00:00.000000  01EF001079NPR013
# 2     32.06         B  2015-01-03T00:00:00.000000  01EF001079NPR013
# 3     32.06         B  2015-01-04T00:00:00.000000  01EF001079NPR013
# 4     32.06         B  2015-01-05T00:00:00.000000  01EF001079NPR013
#
#    pen_int_rate              updated_at
# 0           3.0 2024-08-07 06:57:07.481
# 1           3.0 2024-08-07 06:57:07.481
# 2           3.0 2024-08-07 06:57:07.481
# 3           3.0 2024-08-07 06:57:07.481
# 4           3.0 2024-08-07 06:57:07.481

# %%
# df_c_loan_pen_int = df_c_loan_pen_int.drop(['_airbyte_ab_id', '_airbyte_emitted_at',"source_file_path","_airbyte_additional_properties"], axis=1)

# df_c_loan_pen_int.head()

# %%
df_acid_foracid=pd.read_csv("../../tbaadm/general_acct_mast_table/acid_foracid_masked.csv")
df_acid_foracid.head()
# Out:
#          acid      acid_t         cif_id           foracid  \
# 0   Q39620558  AC10370877  DLNIND1406504  2635752944296001
# 1  Y110180600  AC41672289  DLNIND4211643  3414659520992004
# 2   O93531058  AC73584145  DLNIND4211643  O987952099252401
# 3    32559774  AC12345718  DLNLEG9334212  3241157797524004
# 4   889280082  AC47235600  DLNLEG6576494  0884459092002067
#
#             foracid_t           pan      acct_num                   acct_name
# 0  FA9627239668220084  PAN668645879  272396682200       Humacanta Bipin Thapa
# 1  FA3302344775994664  PAN697945863   23447759946          Sriti Kumari Thapa
# 2  FA5553585851915269  PAN697945863  535858519152          Sriti Kumari Thapa
# 3  FA2582732553674743  PAN353089449  827325536747  PALPA HEALTHCARE PVT. LTD.
# 4  FA7171012596574289  PAN813377590  710125965742                         NaN

# %%
df_result = pd.merge(df_c_loan_pen_int, df_acid_foracid, how='left', on='acid',suffixes=('_p', '_a'))

df_result.head(5)
# Out:
#       acid del_flg due_flg   int_due    prn_due    product    tran_id  \
# 0  0118583       N       B  84341.86  390111.49  390111.49   S9514679
# 1  0118583       N       B  84341.86  390111.49  390111.49   S9526030
# 2  0118583       N       B  84341.86  390111.49  390111.49   S9535617
# 3  0118583       N       B  84341.86  390111.49  390111.49   S9546763
# 4  0118583       N       B  84341.86  390111.49  390111.49   S9558052
#
#    tran_amt trans_flg                   tran_date      loan_account  \
# 0     32.06         B  2015-01-01T00:00:00.000000  01EF001079NPR013
# 1     32.06         B  2015-01-02T00:00:00.000000  01EF001079NPR013
# 2     32.06         B  2015-01-03T00:00:00.000000  01EF001079NPR013
# 3     32.06         B  2015-01-04T00:00:00.000000  01EF001079NPR013
# 4     32.06         B  2015-01-05T00:00:00.000000  01EF001079NPR013
#
#    pen_int_rate              updated_at      acid_t         cif_id  \
# 0           3.0 2024-08-07 06:57:07.481  AC19065472  DLNLEG6465924
# 1           3.0 2024-08-07 06:57:07.481  AC19065472  DLNLEG6465924
# 2           3.0 2024-08-07 06:57:07.481  AC19065472  DLNLEG6465924
# 3           3.0 2024-08-07 06:57:07.481  AC19065472  DLNLEG6465924
# 4           3.0 2024-08-07 06:57:07.481  AC19065472  DLNLEG6465924
#
#             foracid           foracid_t           pan      acct_num acct_name
# 0  01EF001079NPR013  FA5719088150491067  PAN952179235  190881504910       NaN
# 1  01EF001079NPR013  FA5719088150491067  PAN952179235  190881504910       NaN
# 2  01EF001079NPR013  FA5719088150491067  PAN952179235  190881504910       NaN
# 3  01EF001079NPR013  FA5719088150491067  PAN952179235  190881504910       NaN
# 4  01EF001079NPR013  FA5719088150491067  PAN952179235  190881504910       NaN

# %%
df_c_loan_pen_int['acid']=df_result['acid_t']
df_c_loan_pen_int.head()
# Out:
#          acid del_flg due_flg   int_due    prn_due    product    tran_id  \
# 0  AC19065472       N       B  84341.86  390111.49  390111.49   S9514679
# 1  AC19065472       N       B  84341.86  390111.49  390111.49   S9526030
# 2  AC19065472       N       B  84341.86  390111.49  390111.49   S9535617
# 3  AC19065472       N       B  84341.86  390111.49  390111.49   S9546763
# 4  AC19065472       N       B  84341.86  390111.49  390111.49   S9558052
#
#    tran_amt trans_flg                   tran_date      loan_account  \
# 0     32.06         B  2015-01-01T00:00:00.000000  01EF001079NPR013
# 1     32.06         B  2015-01-02T00:00:00.000000  01EF001079NPR013
# 2     32.06         B  2015-01-03T00:00:00.000000  01EF001079NPR013
# 3     32.06         B  2015-01-04T00:00:00.000000  01EF001079NPR013
# 4     32.06         B  2015-01-05T00:00:00.000000  01EF001079NPR013
#
#    pen_int_rate              updated_at
# 0           3.0 2024-08-07 06:57:07.481
# 1           3.0 2024-08-07 06:57:07.481
# 2           3.0 2024-08-07 06:57:07.481
# 3           3.0 2024-08-07 06:57:07.481
# 4           3.0 2024-08-07 06:57:07.481

# %%
df_c_loan_pen_int.to_csv("c_loan_pen_int_masked.csv",index=False)
