# %%
import pandas as pd
df_imis= pd.read_excel("lmis.xlsx")
df_imis.head()
# Out:
#    nta  area ftxt1  ftxt2 ftxt3  ftxt4  ftxt5  ftxt6  ftxt7  ftxt8  ...  \
# 0  NaN   NaN   NaN    NaN   NaN    NaN    NaN    NaN    NaN    NaN  ...
# 1  NaN   NaN   NaN    NaN     A    NaN    NaN    NaN    NaN    NaN  ...
# 2  NaN   NaN   NaN    NaN   NaN    NaN    NaN    NaN    NaN    NaN  ...
# 3  NaN   NaN   NaN    NaN   NaN    NaN    NaN    NaN    NaN    NaN  ...
# 4  NaN   NaN   NaN    NaN   NaN    NaN    NaN    NaN    NaN    NaN  ...
#
#    other_security_value other_security_remark  stock_receivable_value  \
# 0                   NaN                   NaN                     NaN
# 1                   NaN                   NaN                     NaN
# 2                   NaN                   NaN                     NaN
# 3                   NaN                   NaN                     NaN
# 4                   NaN                   NaN                     NaN
#
#   description_of_security  engine_number_of_vehicle  requirement_of_insurance  \
# ...

# %%
df_crmuser_acc=pd.read_csv(r"../../crmuser/account/account_masked.csv")
df_crmuser_acc.head()
# Out:
#           cif_id     orgkey          cust_first_name cust_middle_name  \
# 0  DLNIND6894333  R01562055                    Duman            Biren
# 1  DLNIND4796847  R01911512                  Prajina           Kumari
# 2  DLNIND9732261  R02944296                Humacanta           Prasad
# 3  DLNLEG6793870  C00038863  KHOTANG FOODS PVT. LTD.              NaN
# 4  DLNIND7531716  R01651971                   Adarsh            Kumar
#
#   cust_last_name                    cust_dob   cust_type gender  \
# 0      Timalsina  1989-11-25T00:00:00.000000  INDIVIDUAL      M
# 1         Pandey  1971-05-05T00:00:00.000000  INDIVIDUAL      F
# 2         Pandey  2005-05-18T00:00:00.000000  INDIVIDUAL      M
# 3            NaN  2012-11-12T00:00:00.000000       LEGAL    NaN
# 4        Thakuri  1993-02-28T00:00:00.000000  INDIVIDUAL      M
#
#   marital_status  education  ...  creditbureauscorevalidity  \
# 0           True        NaN  ...                        NaN
# ...

# %%
df_imis['cif_id'].head()
# Out:
# 0    R90504419
# 1    R09092002
# 2    800520784
# 3    RB1499113
# 4    R52273477
# Name: cif_id, dtype: object

# %%
df_result = pd.merge(left=df_imis,right=df_crmuser_acc,left_on='cif_id',right_on='orgkey',suffixes=('_p', '_a'))
df_result.head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\dlytica\masked_original\myenv\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'cif_id'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[34], line 2
# ...

# %%
print(df_imis.shape)
print(df_result.shape)
# Out:
# (52, 58)
# (52, 548)

# %%
df_imis['cif_id']=df_result['cif_id']
df_imis.head()

# %%
df_imis.to_csv("c_loan_pen_int_masked.csv",index=False)
