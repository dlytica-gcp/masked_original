# %%
import pandas as pd
df_date=pd.read_excel("date.xlsx")
df_date.head()
# Out:
#    Week  Year  DW_Id  Month TODAY  DateNum   DayName  Quarter  WeekKey  \
# 0    53  1998      1      1     N    35794  Thursday        1   199753
# 1    53  1998      2      1     N    35795    Friday        1   199753
# 2    53  1998      3      1     N    35796  Saturday        1   199753
# 3     1  1998      4      1     N    35797    Sunday        1   199801
# 4     1  1998      5      1     N    35798    Monday        1   199801
#
#    DW_Batch  ...  Days_in_Nepali_Month  Nepali_Month_End_Tag  \
# 0     16969  ...                   NaN                   NaN
# 1     16969  ...                   NaN                   NaN
# 2     16969  ...                   NaN                   NaN
# 3     16969  ...                   NaN                   NaN
# 4     16969  ...                   NaN                   NaN
#
#   Nepali_Month_End_Date Nepali_Quarter_Number Cummulative_Days_Quarter  \
# 0                   NaN                   7.0                      NaN
# ...

# %%
df_date.to_csv("date_masked.csv",index=False)
