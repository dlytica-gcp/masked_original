# %%
import pandas as pd
df_cat_lang= pd.read_excel("category_lang.xlsx")
df_cat_lang = df_cat_lang.drop(['_airbyte_ab_id', '_airbyte_emitted_at',"source_file_path","_airbyte_additional_properties"], axis=1)

df_cat_lang.head()
# Out:
#                 TMDATE BANK_ID  CATEGORYID  ISEXCEEDED LOCALECODE  \
# 0  2022-12-23T19:20:04      01      402623         NaN      en_US
# 1  2022-12-23T19:20:04      01      402624         NaN      en_US
# 2  2022-12-23T19:20:04      01      402625         NaN      en_US
# 3  2022-12-23T19:20:04      01      402626         NaN      en_US
# 4  2022-12-23T19:20:04      01      402627         NaN      en_US
#
#          LOCALETEXT CMLABELCODE  CATEGORYLANGID LOCALETEXT_ALT  \
# 0        BHUMLICHOK         NaN          502623            NaN
# 1         BHUMESWOR         NaN          502624            NaN
# 2     BHUWANPOKHARI         NaN          502625            NaN
# 3          BHURTUNG         NaN          502626            NaN
# 4  BHURUNG TATOPANI         NaN          502627            NaN
#
#                updated_at
# 0 2024-08-07 06:34:53.955
# 1 2024-08-07 06:34:53.955
# 2 2024-08-07 06:34:53.955
# 3 2024-08-07 06:34:53.955
# 4 2024-08-07 06:34:53.955

# %%
df_cat_lang.to_csv('category_lang_masked.csv', index=False)
