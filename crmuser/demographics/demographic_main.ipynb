# %%
import pandas as pd

# %%
df_demographic= pd.read_excel("demographic.xlsx")
df_demographic.head()
# Out:
#                          _airbyte_ab_id     _airbyte_emitted_at  url  alert1  \
# 0  b32a27fa-e3f7-4c00-b2a9-bfb084b1da3c 2024-08-05 07:02:37.777  NaN     NaN
# 1  a5419b64-0960-48c4-8a13-827e1be7cdbf 2024-08-05 07:02:37.777  NaN     NaN
# 2  1305ca97-751a-4f41-9843-470df14854ad 2024-08-05 07:02:37.777  NaN     NaN
# 3  3c1a0845-ad46-46e8-9c7d-1535a95cb380 2024-08-05 07:02:37.777  NaN     NaN
# 4  0bab3c67-470a-4fbd-9118-1a4595a7280c 2024-08-05 07:02:37.777  NaN     NaN
#
#    alert2  alert3  alert4  alert5     orgkey               tmdate  ...  \
# 0     NaN     NaN     NaN     NaN  R00185654  2022-12-23T19:20:05  ...
# 1     NaN     NaN     NaN     NaN  R00816195  2022-12-23T19:20:05  ...
# 2     NaN     NaN     NaN     NaN  R01014498  2022-12-23T19:20:05  ...
# 3     NaN     NaN     NaN     NaN  R47430440  2022-12-23T19:20:05  ...
# 4     NaN     NaN     NaN     NaN  R02063811  2022-12-23T19:20:05  ...
#
#    selfempdepreciationprioryear  selfempgrossreceiptprioryear  \
# ...

# %%
df_account=pd.read_csv(r"..\account\account_masked.csv")
df_account.head()
# Out:
#           cif_id     orgkey               cust_first_name cust_middle_name  \
# 0  DLNIND8613742  R01516157                     Prashanta             Babu
# 1  DLNIND3162611  R01651971                       Veshraj              NaN
# 2  DLNIND1414575  R09396490                        sandal              NaN
# 3  DLNLEG2163717  R22132679  MANANG HOSPITALITY PVT. LTD.              NaN
# 4  DLNIND1962912  R00580783                        Kabita              NaN
#
#   cust_last_name                    cust_dob   cust_type gender  \
# 0          Thapa  1966-05-06T00:00:00.000000  INDIVIDUAL      M
# 1        Mainali  1993-02-28T00:00:00.000000  INDIVIDUAL      M
# 2       Tandukar  2013-01-09T00:00:00.000000  INDIVIDUAL      M
# 3            NaN  1900-01-01T00:00:00.000000       LEGAL    NaN
# 4      Bhattarai  2000-01-01T00:00:00.000000  INDIVIDUAL      M
#
#   marital_status  education  ...  sencitizenconversionflag  \
# 0           True        NaN  ...                       NaN
# ...

# %%
df_demographic = df_demographic.drop(['_airbyte_ab_id', '_airbyte_emitted_at',"source_file_path","_airbyte_additional_properties"], axis=1)

df_demographic.head()
# Out:
#    url  alert1  alert2  alert3  alert4  alert5     orgkey  \
# 0  NaN     NaN     NaN     NaN     NaN     NaN  R00185654
# 1  NaN     NaN     NaN     NaN     NaN     NaN  R00816195
# 2  NaN     NaN     NaN     NaN     NaN     NaN  R01014498
# 3  NaN     NaN     NaN     NaN     NaN     NaN  R47430440
# 4  NaN     NaN     NaN     NaN     NaN     NaN  R02063811
#
#                 tmdate  amount1  amount2  ...  cu_selfempnetprofitcurrentyr  \
# 0  2022-12-23T19:20:05      NaN      NaN  ...                           NPR
# 1  2022-12-23T19:20:05      NaN      NaN  ...                           NPR
# 2  2022-12-23T19:20:05      NaN      NaN  ...                           NPR
# 3  2022-12-23T19:20:05      NaN      NaN  ...                           NaN
# 4  2022-12-23T19:20:05      NaN      NaN  ...                           NaN
#
#    selfempaverageannualturnover  selfempdepreciationprioryear  \
# 0                           NaN                           NaN
# ...

# %%
df_result = pd.merge(df_demographic, df_account, how='left', on='orgkey',suffixes=('_p', '_a'))

df_result[["orgkey","cif_id"]].head(80)
# Out:
#        orgkey         cif_id
# 0   R00185654  DLNIND8532441
# 1   R00816195  DLNIND7513477
# 2   R01014498  DLNIND5554674
# 3   R47430440  DLNIND3663926
# 4   R02063811  DLNIND4038457
# ..        ...            ...
# 66  R01911519  DLNIND8408194
# 67  R01911516  DLNIND1694858
# 68  R01911512  DLNIND6126826
# 69  R01911511  DLNIND3809257
# 70  R01847463  DLNIND9834525
#
# [71 rows x 2 columns]

# %%
df_result.shape
# Out:
# (71, 734)

# %%
df_demographic.shape
# Out:
# (71, 245)

# %%
df_result.columns
# Out:
# Index(['url_p', 'alert1_p', 'alert2_p', 'alert3_p', 'alert4', 'alert5',
#        'orgkey', 'tmdate_p', 'amount1_p', 'amount2_p',
#        ...
#        'sencitizenconversionflag', 'creditbureauscorevalidity',
#        'foreignacctaxreportingreq', 'foreigntaxreportingstatus',
#        'preferred_mobile_alert_no', 'credithistoryrequestedflag',
#        'foreigntaxreportingcountry', 'customer_level_provisioning',
#        'preferred_mobile_alert_type', 'updated_at_a'],
#       dtype='object', length=734)

# %%
df_demographic.head()
# Out:
#    url  alert1  alert2  alert3  alert4  alert5     orgkey  \
# 0  NaN     NaN     NaN     NaN     NaN     NaN  R00185654
# 1  NaN     NaN     NaN     NaN     NaN     NaN  R00816195
# 2  NaN     NaN     NaN     NaN     NaN     NaN  R01014498
# 3  NaN     NaN     NaN     NaN     NaN     NaN  R47430440
# 4  NaN     NaN     NaN     NaN     NaN     NaN  R02063811
#
#                 tmdate  amount1  amount2  ...  cu_selfempnetprofitcurrentyr  \
# 0  2022-12-23T19:20:05      NaN      NaN  ...                           NPR
# 1  2022-12-23T19:20:05      NaN      NaN  ...                           NPR
# 2  2022-12-23T19:20:05      NaN      NaN  ...                           NPR
# 3  2022-12-23T19:20:05      NaN      NaN  ...                           NaN
# 4  2022-12-23T19:20:05      NaN      NaN  ...                           NaN
#
#    selfempaverageannualturnover  selfempdepreciationprioryear  \
# 0                           NaN                           NaN
# ...

# %%
df_account.head()
# Out:
#           cif_id     orgkey               cust_first_name cust_middle_name  \
# 0  DLNIND8613742  R01516157                     Prashanta             Babu
# 1  DLNIND3162611  R01651971                       Veshraj              NaN
# 2  DLNIND1414575  R09396490                        sandal              NaN
# 3  DLNLEG2163717  R22132679  MANANG HOSPITALITY PVT. LTD.              NaN
# 4  DLNIND1962912  R00580783                        Kabita              NaN
#
#   cust_last_name                    cust_dob   cust_type gender  \
# 0          Thapa  1966-05-06T00:00:00.000000  INDIVIDUAL      M
# 1        Mainali  1993-02-28T00:00:00.000000  INDIVIDUAL      M
# 2       Tandukar  2013-01-09T00:00:00.000000  INDIVIDUAL      M
# 3            NaN  1900-01-01T00:00:00.000000       LEGAL    NaN
# 4      Bhattarai  2000-01-01T00:00:00.000000  INDIVIDUAL      M
#
#   marital_status  education  ...  sencitizenconversionflag  \
# 0           True        NaN  ...                       NaN
# ...

# %%
df_demographic['orgkey']=df_result['cif_id']

# %%
df_demographic.head()
# Out:
#    url  alert1  alert2  alert3  alert4  alert5         orgkey  \
# 0  NaN     NaN     NaN     NaN     NaN     NaN  DLNIND8532441
# 1  NaN     NaN     NaN     NaN     NaN     NaN  DLNIND7513477
# 2  NaN     NaN     NaN     NaN     NaN     NaN  DLNIND5554674
# 3  NaN     NaN     NaN     NaN     NaN     NaN  DLNIND3663926
# 4  NaN     NaN     NaN     NaN     NaN     NaN  DLNIND4038457
#
#                 tmdate  amount1  amount2  ...  cu_selfempnetprofitcurrentyr  \
# 0  2022-12-23T19:20:05      NaN      NaN  ...                           NPR
# 1  2022-12-23T19:20:05      NaN      NaN  ...                           NPR
# 2  2022-12-23T19:20:05      NaN      NaN  ...                           NPR
# 3  2022-12-23T19:20:05      NaN      NaN  ...                           NaN
# 4  2022-12-23T19:20:05      NaN      NaN  ...                           NaN
#
#    selfempaverageannualturnover  selfempdepreciationprioryear  \
# 0                           NaN                           NaN
# ...

# %%
df_demographic['phoneno']=result_df['preferredphone']
df_demographic['phoneno'].head()
# Out:
# 0   -9.830140e+09
# 1   -9.873611e+09
# 2   -9.844324e+09
# 3   -9.834018e+09
# 4   -9.883512e+09
# Name: phoneno, dtype: float64

# %%
df_demographic.to_csv('demographic_masked.csv', index=False)
