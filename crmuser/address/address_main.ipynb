# %%
import pandas as pd

# %%
df_address = pd.read_excel("address.xlsx")
df_address.head()
# Out:
#                          _airbyte_ab_id     _airbyte_emitted_at  url    zip  \
# 0  332f8978-6edc-45ca-b88b-944612a4f29c 2024-08-05 07:02:37.777  NaN      .
# 1  980308d0-a42b-4912-8859-d0b9d334d3d1 2024-08-05 07:02:37.777  NaN      .
# 2  b91e4274-6e52-4b9e-ba84-49d4b250694c 2024-08-05 07:02:37.777  NaN    NaN
# 3  9b1c3de4-1069-46b3-bbc3-71a9cb162e59 2024-08-05 07:02:37.777  NaN  97700
# 4  7ef9c5e7-a154-429e-b521-167d89f29764 2024-08-05 07:02:37.777  NaN  97700
#
#     city                                     name  town  email  faxno  orgid  \
# 0  BUTWA  BISALPATH SADAK NIRMAN UPABHOKTA SAMITI   NaN    NaN    NaN    NaN
# 1  BUTWA  BISALPATH SADAK NIRMAN UPABHOKTA SAMITI   NaN    NaN    NaN    NaN
# 2    NaN  BISALPATH SADAK NIRMAN UPABHOKTA SAMITI   NaN    NaN    NaN    NaN
# 3    NaN                             INDIRA ARYAL   NaN    NaN    NaN    NaN
# 4    NaN                             INDIRA ARYAL   NaN    NaN    NaN    NaN
#
# ...

# %%
df_address = df_address.drop(['_airbyte_ab_id', '_airbyte_emitted_at',"source_file_path"], axis=1)
df_address.head()
# Out:
#    url    zip   city                                     name  town  email  \
# 0  NaN      .  BUTWA  BISALPATH SADAK NIRMAN UPABHOKTA SAMITI   NaN    NaN
# 1  NaN      .  BUTWA  BISALPATH SADAK NIRMAN UPABHOKTA SAMITI   NaN    NaN
# 2  NaN    NaN    NaN  BISALPATH SADAK NIRMAN UPABHOKTA SAMITI   NaN    NaN
# 3  NaN  97700    NaN                             INDIRA ARYAL   NaN    NaN
# 4  NaN  97700    NaN                             INDIRA ARYAL   NaN    NaN
#
#    faxno  orgid  state  telex  ...  phoneno2localcode  residentialstatus  \
# 0    NaN    NaN  RUPAN    NaN  ...                NaN                NaN
# 1    NaN    NaN  RUPAN    NaN  ...                NaN                NaN
# 2    NaN    NaN    NaN    NaN  ...                NaN                NaN
# 3    NaN    NaN  NUWAK    NaN  ...                NaN                NaN
# 4    NaN    NaN  NUWAK    NaN  ...                NaN                NaN
#
#   pagernocountrycode  holdmailinitiatedby phoneno1countrycode  \
# ...

# %%
df_address["orgkey"]
# Out:
# 0      C00004457
# 1      C00004457
# 2      C00004457
# 3      R00134245
# 4      R00134245
#          ...
# 382    R01786441
# 383    R01786441
# 384    R01786442
# 385    R01786442
# 386    R01786442
# Name: orgkey, Length: 387, dtype: object

# %%
print(len(df_address))
# Out:
# 387

# %%
df = pd.read_csv("final_table.csv")
df.head()
# Out:
#           cif_id     orgkey                   cust_first_name  \
# 0  DLNIND7725854  R01516157                         Prashanta
# 1  DLNIND7733479  R01651971                          Prashant
# 2  DLNIND7579682  R09396490                            Kabita
# 3  DLNLEG2540588  R22132679  KAILASH PRINTING PRESS PVT. LTD.
# 4  DLNIND4399480  R00580783                            sandil
#
#   cust_middle_name cust_last_name                    cust_dob   cust_type  \
# 0             Babu          Thapa  1966-05-06T00:00:00.000000  INDIVIDUAL
# 1              NaN          Nepal  1993-02-28T00:00:00.000000  INDIVIDUAL
# 2              NaN      Bhattarai  2013-01-09T00:00:00.000000  INDIVIDUAL
# 3              NaN            NaN  1900-01-01T00:00:00.000000       LEGAL
# 4              NaN       Tandukar  2000-01-01T00:00:00.000000  INDIVIDUAL
#
#   gender marital_status  education  ...  sencitizenconversionflag  \
# 0      M           True        NaN  ...                       NaN
# ...

# %%
df.columns
# Out:
# Index(['cif_id', 'orgkey', 'cust_first_name', 'cust_middle_name',
#        'cust_last_name', 'cust_dob', 'cust_type', 'gender', 'marital_status',
#        'education',
#        ...
#        'sencitizenconversionflag', 'creditbureauscorevalidity',
#        'foreignacctaxreportingreq', 'foreigntaxreportingstatus',
#        'preferred_mobile_alert_no', 'credithistoryrequestedflag',
#        'foreigntaxreportingcountry', 'customer_level_provisioning',
#        'preferred_mobile_alert_type', 'updated_at'],
#       dtype='object', length=490)

# %%
print(len(df.columns))
# Out:
# 490

# %%
# Out:
#           cif_id     orgkey                   cust_first_name  \
# 0  DLNIND7725854  R01516157                         Prashanta
# 1  DLNIND7733479  R01651971                          Prashant
# 2  DLNIND7579682  R09396490                            Kabita
# 3  DLNLEG2540588  R22132679  KAILASH PRINTING PRESS PVT. LTD.
# 4  DLNIND4399480  R00580783                            sandil
#
#   cust_middle_name cust_last_name                    cust_dob   cust_type  \
# 0             Babu          Thapa  1966-05-06T00:00:00.000000  INDIVIDUAL
# 1              NaN          Nepal  1993-02-28T00:00:00.000000  INDIVIDUAL
# 2              NaN      Bhattarai  2013-01-09T00:00:00.000000  INDIVIDUAL
# 3              NaN            NaN  1900-01-01T00:00:00.000000       LEGAL
# 4              NaN       Tandukar  2000-01-01T00:00:00.000000  INDIVIDUAL
#
#   gender marital_status  education  ...  sencitizenconversionflag  \
# 0      M           True        NaN  ...                       NaN
# ...

# %%
result_df = pd.merge(df_address, df, how='left', on='orgkey',suffixes=('_add', '_acc'))
result_df.head()
# Out:
#    url_add zip_add city_add                                 name_add  town  \
# 0      NaN       .    BUTWA  BISALPATH SADAK NIRMAN UPABHOKTA SAMITI   NaN
# 1      NaN       .    BUTWA  BISALPATH SADAK NIRMAN UPABHOKTA SAMITI   NaN
# 2      NaN     NaN      NaN  BISALPATH SADAK NIRMAN UPABHOKTA SAMITI   NaN
# 3      NaN   97700      NaN                             INDIRA ARYAL   NaN
# 4      NaN   97700      NaN                             INDIRA ARYAL   NaN
#
#    email_add  faxno  orgid state_add  telex  ...  sencitizenconversionflag  \
# 0        NaN    NaN    NaN     RUPAN    NaN  ...                       NaN
# 1        NaN    NaN    NaN     RUPAN    NaN  ...                       NaN
# 2        NaN    NaN    NaN       NaN    NaN  ...                       NaN
# 3        NaN    NaN    NaN     NUWAK    NaN  ...                       NaN
# 4        NaN    NaN    NaN     NUWAK    NaN  ...                       NaN
#
#    creditbureauscorevalidity foreignacctaxreportingreq  \
# ...

# %%
df_address[['orgkey','name']] = result_df[['cif_id','cust_first_name']]
df_address[['orgkey','name']].head(30)
# Out:
#            orgkey                             name
# 0   DLNLEG2622635          KHOTANG FOODS PVT. LTD.
# 1   DLNLEG2622635          KHOTANG FOODS PVT. LTD.
# 2   DLNLEG2622635          KHOTANG FOODS PVT. LTD.
# 3   DLNIND7541103                            Nawal
# 4   DLNIND7541103                            Nawal
# 5   DLNIND7541103                            Nawal
# 6   DLNIND5055086                      Hrisheekesh
# 7   DLNIND5055086                      Hrisheekesh
# 8   DLNIND5055086                      Hrisheekesh
# 9   DLNIND2688816                          Prabina
# 10  DLNIND2688816                          Prabina
# 11  DLNIND2688816                          Prabina
# 12  DLNLEG8912000      TAMOR ELECTRONICS PVT. LTD.
# 13  DLNLEG8912000      TAMOR ELECTRONICS PVT. LTD.
# 14  DLNLEG8912000      TAMOR ELECTRONICS PVT. LTD.
# 15  DLNIND2861284                           Dipika
# 16  DLNIND2861284                           Dipika
# ...

# %%
new_data = result_df[['cif_id', 'email_acc'
]]\
            .rename(columns={
                "cif_id":"orgkey",
                "email_acc": "email",

            })
new_data.head()
# Out:
#           orgkey                        email
# 0  DLNLEG2622635  khotangfoods237@outlook.com
# 1  DLNLEG2622635  khotangfoods237@outlook.com
# 2  DLNLEG2622635  khotangfoods237@outlook.com
# 3  DLNIND7541103           nawal148@gmail.com
# 4  DLNIND7541103           nawal148@gmail.com

# %%
print(len(new_data))
# Out:
# 387
