# %%
import pandas as pd

# %%
df_address = pd.read_excel("address.xlsx")
df_address.head()
# Out:
#                          _airbyte_ab_id     _airbyte_emitted_at  url    zip  \
# 0  332f8978-6edc-45ca-b88b-944612a4f29c 2024-08-05 07:02:37.777  NaN      .
# 1  980308d0-a42b-4912-8859-d0b9d334d3d1 2024-08-05 07:02:37.777  NaN      .
# 2  b91e4274-6e52-4b9e-ba84-49d4b250694c 2024-08-05 07:02:37.777  NaN    NaN
# 3  9b1c3de4-1069-46b3-bbc3-71a9cb162e59 2024-08-05 07:02:37.777  NaN  97700
# 4  7ef9c5e7-a154-429e-b521-167d89f29764 2024-08-05 07:02:37.777  NaN  97700
#
#     city                                     name  town  email  faxno  orgid  \
# 0  BUTWA  BISALPATH SADAK NIRMAN UPABHOKTA SAMITI   NaN    NaN    NaN    NaN
# 1  BUTWA  BISALPATH SADAK NIRMAN UPABHOKTA SAMITI   NaN    NaN    NaN    NaN
# 2    NaN  BISALPATH SADAK NIRMAN UPABHOKTA SAMITI   NaN    NaN    NaN    NaN
# 3    NaN                             INDIRA ARYAL   NaN    NaN    NaN    NaN
# 4    NaN                             INDIRA ARYAL   NaN    NaN    NaN    NaN
#
# ...

# %%
df_address = df_address.drop(['_airbyte_ab_id', '_airbyte_emitted_at',"source_file_path"], axis=1)
df_address.head()
# Out:
#    url    zip   city                                     name  town  email  \
# 0  NaN      .  BUTWA  BISALPATH SADAK NIRMAN UPABHOKTA SAMITI   NaN    NaN
# 1  NaN      .  BUTWA  BISALPATH SADAK NIRMAN UPABHOKTA SAMITI   NaN    NaN
# 2  NaN    NaN    NaN  BISALPATH SADAK NIRMAN UPABHOKTA SAMITI   NaN    NaN
# 3  NaN  97700    NaN                             INDIRA ARYAL   NaN    NaN
# 4  NaN  97700    NaN                             INDIRA ARYAL   NaN    NaN
#
#    faxno  orgid  state  telex  ...  phoneno2localcode  residentialstatus  \
# 0    NaN    NaN  RUPAN    NaN  ...                NaN                NaN
# 1    NaN    NaN  RUPAN    NaN  ...                NaN                NaN
# 2    NaN    NaN    NaN    NaN  ...                NaN                NaN
# 3    NaN    NaN  NUWAK    NaN  ...                NaN                NaN
# 4    NaN    NaN  NUWAK    NaN  ...                NaN                NaN
#
#   pagernocountrycode  holdmailinitiatedby phoneno1countrycode  \
# ...

# %%
print(len(df_address))
# Out:
# 387

# %%
df_acc = pd.read_csv("../account/account_masked.csv")
df_acc.head()
# Out:
#           cif_id     orgkey          cust_first_name cust_middle_name  \
# 0  DLNIND1575690  R01562055                    Duman            Biren
# 1  DLNIND5073099  R01911512                  Prajina           Kumari
# 2  DLNIND3879318  R02944296                Humacanta           Prasad
# 3  DLNLEG4254558  C00038863  KHOTANG FOODS PVT. LTD.              NaN
# 4  DLNIND6006816  R01651971                   Adarsh            Kumar
#
#   cust_last_name                    cust_dob   cust_type gender  \
# 0      Timalsina  1989-11-25T00:00:00.000000  INDIVIDUAL      M
# 1         Pandey  1971-05-05T00:00:00.000000  INDIVIDUAL      F
# 2         Pandey  2005-05-18T00:00:00.000000  INDIVIDUAL      M
# 3            NaN  2012-11-12T00:00:00.000000       LEGAL    NaN
# 4        Thakuri  1993-02-28T00:00:00.000000  INDIVIDUAL      M
#
#   marital_status  education  ...  creditbureauscorevalidity  \
# 0          False        NaN  ...                        NaN
# ...

# %%
print(len(df_acc.columns))
# Out:
# 491

# %%
result_df = pd.merge(df_address, df_acc, how='left', on='orgkey',suffixes=('_add', '_acc'))
result_df.head()
# Out:
#    url_add zip_add city_add                                 name_add  town  \
# 0      NaN       .    BUTWA  BISALPATH SADAK NIRMAN UPABHOKTA SAMITI   NaN
# 1      NaN       .    BUTWA  BISALPATH SADAK NIRMAN UPABHOKTA SAMITI   NaN
# 2      NaN     NaN      NaN  BISALPATH SADAK NIRMAN UPABHOKTA SAMITI   NaN
# 3      NaN   97700      NaN                             INDIRA ARYAL   NaN
# 4      NaN   97700      NaN                             INDIRA ARYAL   NaN
#
#    email_add  faxno  orgid state_add  telex  ...  creditbureauscorevalidity  \
# 0        NaN    NaN    NaN     RUPAN    NaN  ...                        NaN
# 1        NaN    NaN    NaN     RUPAN    NaN  ...                        NaN
# 2        NaN    NaN    NaN       NaN    NaN  ...                        NaN
# 3        NaN    NaN    NaN     NUWAK    NaN  ...                        NaN
# 4        NaN    NaN    NaN     NUWAK    NaN  ...                        NaN
#
#    foreignacctaxreportingreq foreigntaxreportingstatus  \
# ...

# %%
df_address["orgkey"] = result_df["cif_id"].values
df_address["name"] = result_df["name_acc"].values
df_address["state"] = result_df["state_acc"].values
df_address["bank_id"] = result_df["bank_id_acc"].values
df_address["address_line1"] = result_df["address_line1_acc"].values
df_address["address_line2"] = result_df["address_line2_acc"].values
df_address["address_line3"] = result_df["address_line3_acc"].values
df_address["city"] = result_df["city_acc"].values
df_address["city"] = result_df["city_acc"].values
df_address["swift_name"] = result_df["name_acc"].values
df_address.head()
# Out:
#    url    zip   city                         name  town  email  faxno  orgid  \
# 0  NaN      .  BUTWA  TAMOR ELECTRONICS PVT. LTD.   NaN    NaN    NaN    NaN
# 1  NaN      .  BUTWA  TAMOR ELECTRONICS PVT. LTD.   NaN    NaN    NaN    NaN
# 2  NaN    NaN  BUTWA  TAMOR ELECTRONICS PVT. LTD.   NaN    NaN    NaN    NaN
# 3  NaN  97700    NaN          Nawal Bibek Thakuri   NaN    NaN    NaN    NaN
# 4  NaN  97700    NaN          Nawal Bibek Thakuri   NaN    NaN    NaN    NaN
#
#    state  telex  ...  phoneno2localcode  residentialstatus pagernocountrycode  \
# 0  RUPAN    NaN  ...                NaN                NaN                NaN
# 1  RUPAN    NaN  ...                NaN                NaN                NaN
# 2  RUPAN    NaN  ...                NaN                NaN                NaN
# 3  NUWAK    NaN  ...                NaN                NaN                NaN
# 4  NUWAK    NaN  ...                NaN                NaN                NaN
#
# ...

# %%
df_address.to_csv('address_masked.csv', index=False)
