# %%
from sqlalchemy import create_engine
import pandas as pd

# Step 1: Read Excel file
  # Replace with your file path

# Step 2: Create SQLAlchemy engine
engine = create_engine('postgresql+psycopg2://postgres:prashanta@localhost:5432/original')

# Step 3: Dump data into PostgreSQL (use 'replace', 'append', or 'fail')
df.to_sql(
    'phoneemail',          # Table name
    engine,                # SQLAlchemy engine
    if_exists='replace',   # Options: 'fail', 'replace', 'append'
    index=False            # Skip writing DataFrame index
)

print("Data successfully exported to PostgreSQL!")
# Out:
# Data successfully exported to PostgreSQL!

# %%
conn = psycopg2.connect(
    dbname="original.crm_final",
    user="postgres",
    password="prashanta",
    host="localhost",
    port="5432"
)
# SQL query to fetch data
query = "SELECT * FROM account_customer;"

df_acccount = pd.read_sql_query(query, conn)


conn.close()

df_acccount.head()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_24600\2110470066.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_acccount = pd.read_sql_query(query, conn)
#           cif_id                   cust_first_name cust_middle_name  \
# 0  DLNIND9508923                             Neeti             Maya
# 1  DLNIND1647243                         Aparajita             Maya
# 2  DLNIND8284039                            Nishar            Laxmi
# 3  DLNLEG6645569  KAILASH PRINTING PRESS PVT. LTD.             None
# 4  DLNIND5790376                              Smit           Bishnu
#
#   cust_last_name                    cust_dob   cust_type education  pan  \
# 0          Magar  1966-05-06T00:00:00.000000  INDIVIDUAL      None  NaN
# 1         Tamang  1993-02-28T00:00:00.000000  INDIVIDUAL      None  NaN
# ...

# %%
df_phoneemail = pd.read_excel("phoneemail.xlsx")
df_phoneemail.head()
# Out:
#                          _airbyte_ab_id     _airbyte_emitted_at  url  date1  \
# 0  445c20d7-6fca-4156-8da1-d935a8d83e3e 2024-08-05 07:02:37.777  NaN    NaN
# 1  00e99ff2-d9e9-4f71-bbef-fadd1ad51bdb 2024-08-05 07:02:37.777  NaN    NaN
# 2  ec94bcbc-4bc8-4f67-b2af-5c96b12daf28 2024-08-05 07:02:37.777  NaN    NaN
# 3  706ec467-2440-4210-846c-50aa5549f178 2024-08-05 07:02:37.777  NaN    NaN
# 4  9eb9527b-ba69-45fa-ae41-1c55debd0920 2024-08-05 07:02:37.777  NaN    NaN
#
#    date2  date3 email  orgid     orgkey               tmdate  ...  \
# 0    NaN    NaN   NaN    NaN  R90504419  2022-12-23T19:20:07  ...
# 1    NaN    NaN   NaN    NaN  R90504419  2022-12-23T19:20:07  ...
# 2    NaN    NaN   NaN    NaN  R90504419  2022-12-23T19:20:07  ...
# 3    NaN    NaN   NaN    NaN  R39227100  2022-12-23T19:20:07  ...
# 4    NaN    NaN   NaN    NaN  R39227100  2022-12-23T19:20:07  ...
#
#    noncustomerid  preferredflag workextension  phoneemailtype  \
# ...

# %%
df_phoneemail = pd.read_csv("final_table.csv")
df_phoneemail.head()
