# %%
import pandas as pd
df_bankxp_cust=pd.read_excel("customer.xlsx")
df_bankxp_cust.head()
# Out:
#    id mode active     cbs_id gender                 address approved  \
# 0  22    A      D  019898447      M  JUREPI GALLI-14 HN:239        D
# 1  23    A      D  R00745672      M             DANFE MARGA        D
# 2  24    A      D  R00858406      M                  IMADOL        D
# 3  25    A      D  R00108041      M             BATISPUTALI        D
# 4  26    A      D  R00842883      M                 CHYASAL        D
#
#    language qr_login ac_holder  ...  delete_approved_by edit_approved_date  \
# 0       NaN        N         Y  ...                 4.0                NaN
# 1       NaN        N         Y  ...                 5.0                NaN
# 2       NaN        N         Y  ...                 4.0                NaN
# 3       NaN        N         Y  ...                 4.0                NaN
# 4       NaN        N         Y  ...                 4.0                NaN
#
#    last_modified_date                              deleted_approved_date  \
# ...

# %%
df_cif_mask=pd.read_csv(r"..\..\crmuser\account\cif_masked.csv")
df_cif_mask.head()
# Out:
#           cif_id     orgkey          cust_first_name cust_middle_name  \
# 0  DLNIND4568821  R01562055                    Duman          Narayan
# 1  DLNIND7235296  R01911512                  Prajina             Devi
# 2  DLNIND1406504  R02944296                Humacanta            Bipin
# 3  DLNLEG6218579  C00038863  KHOTANG FOODS PVT. LTD.              NaN
# 4  DLNIND1255130  R01651971                   Adarsh           Bhakta
#
#   cust_last_name  preferredphone                  preferredname  \
# 0        Neupane     -9833329213          Duman Narayan Neupane
# 1       Maharjan     -9892306612          Prajina Devi Maharjan
# 2          Thapa     -9856817476          Humacanta Bipin Thapa
# 3            NaN     -9862720425  MANASLU HOSPITALITY PVT. LTD.
# 4           Lama     -9810012680             Adarsh Bhakta Lama
#
#              preferredemail                        email gender  \
# 0     ARYALPRABAL@GMAIL.COM           duman492@gmail.com      M
# ...

# %%
df_acidfor_mask=pd.read_csv(r"..\..\tbaadm\general_acct_mast_table\acid_foracid_masked.csv")
df_acidfor_mask.head()
# Out:
#          acid      acid_t         cif_id           foracid  \
# 0   Q39620558  AC10370877  DLNIND1406504  2635752944296001
# 1  Y110180600  AC41672289  DLNIND4211643  3414659520992004
# 2   O93531058  AC73584145  DLNIND4211643  O987952099252401
# 3    32559774  AC12345718  DLNLEG9334212  3241157797524004
# 4   889280082  AC47235600  DLNLEG6576494  0884459092002067
#
#             foracid_t           pan      acct_num                   acct_name
# 0  FA9627239668220084  PAN668645879  272396682200       Humacanta Bipin Thapa
# 1  FA3302344775994664  PAN697945863   23447759946          Sriti Kumari Thapa
# 2  FA5553585851915269  PAN697945863  535858519152          Sriti Kumari Thapa
# 3  FA2582732553674743  PAN353089449  827325536747  PALPA HEALTHCARE PVT. LTD.
# 4  FA7171012596574289  PAN813377590  710125965742                         NaN

# %%
result = pd.merge(df_bankxp_cust, df_cif_mask,left_on='cbs_id',right_on='orgkey',suffixes=('_p', '_a'))

result['cif_id'].head(5)
# Out:
# 0    DLNIND9286944
# 1    DLNIND1498614
# 2    DLNIND6021714
# 3    DLNIND1842225
# 4    DLNIND9286944
# Name: cif_id, dtype: object

# %%
df_result = pd.merge(result, df_acidfor_mask,on='cif_id',suffixes=('_p', '_a'))

df_result['gender_a'].sample(20)
# Out:
# 46    M
# 64    M
# 7     M
# 71    M
# 56    M
# 37    F
# 67    M
# 29    M
# 12    M
# 5     M
# 25    M
# 16    M
# 48    M
# 52    M
# 58    M
# 17    M
# 14    M
# 15    F
# 65    M
# 35    M
# Name: gender_a, dtype: object

# %%
print(df_result.shape)
print(df_bankxp_cust.shape)
# Out:
# (82, 69)
# (1280, 50)

# %%
 df_bankxp_cust[['cbs_id','gender','last_name','first_name','middle_name','mobile_number','email_address']]=df_result[['cif_id','gender_a','cust_first_name',
                                                                            'cust_middle_name','cust_last_name','preferredphone','email']]


 df_bankxp_cust.head(6)
# Out:
#    id mode active         cbs_id gender                  address approved  \
# 0  22    A      D  DLNIND9286944      M   JUREPI GALLI-14 HN:239        D
# 1  23    A      D  DLNIND9286944      M              DANFE MARGA        D
# 2  24    A      D  DLNIND9286944      M                   IMADOL        D
# 3  25    A      D  DLNIND9286944      M              BATISPUTALI        D
# 4  26    A      D  DLNIND9286944      M                  CHYASAL        D
# 5  27    A      D  DLNIND9286944      M  NEW BANESWOR, KATHMANDU        D
#
#    language qr_login ac_holder  ...  delete_approved_by edit_approved_date  \
# 0       NaN        N         Y  ...                 4.0                NaN
# 1       NaN        N         Y  ...                 5.0                NaN
# 2       NaN        N         Y  ...                 4.0                NaN
# 3       NaN        N         Y  ...                 4.0                NaN
# ...

# %%
df_bankxp_cust[['cbs_id','gender']]=df_result[['cif_id','gender_a']]


df_bankxp_cust.head()
# Out:
#    id mode active         cbs_id gender                 address approved  \
# 0  22    A      D  DLNIND9286944      M  JUREPI GALLI-14 HN:239        D
# 1  23    A      D  DLNIND9286944      M             DANFE MARGA        D
# 2  24    A      D  DLNIND9286944      M                  IMADOL        D
# 3  25    A      D  DLNIND9286944      M             BATISPUTALI        D
# 4  26    A      D  DLNIND9286944      M                 CHYASAL        D
#
#    language qr_login ac_holder  ...  delete_approved_by edit_approved_date  \
# 0       NaN        N         Y  ...                 4.0                NaN
# 1       NaN        N         Y  ...                 5.0                NaN
# 2       NaN        N         Y  ...                 4.0                NaN
# 3       NaN        N         Y  ...                 4.0                NaN
# 4       NaN        N         Y  ...                 4.0                NaN
#
#    last_modified_date                              deleted_approved_date  \
# ...
