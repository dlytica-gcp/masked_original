# %%
import pandas as pd
df_bankxp_login_acces=pd.read_excel("login_access_channel.xlsx")
df_bankxp_login_acces.head()
# Out:
#     id active  added_by                                         added_date  \
# 0  225      Y         1  Row(member0=Timestamp('2022-03-20 06:07:12'), ...
# 1  226      Y         1  Row(member0=Timestamp('2022-03-20 06:07:12'), ...
# 2  227      Y         1  Row(member0=Timestamp('2022-03-20 06:15:00'), ...
# 3  228      Y         1  Row(member0=Timestamp('2022-03-20 06:15:00'), ...
# 4  229      Y         1  Row(member0=Timestamp('2022-03-20 22:32:36'), ...
#
#    migration_id login_blocked  login_channel  last_login_date  \
# 0           NaN             N            NaN              NaN
# 1           NaN             N            NaN              NaN
# 2           NaN             N            NaN              NaN
# 3           NaN             N            NaN              NaN
# 4           NaN             N            NaN              NaN
#
#    request_attempt  last_modified_by login_block_date  login_block_mode  \
# ...

# %%
df_bankxp_login_acces.to_csv("bankxp_login_acces_masked.csv",index=False)
