# %%
import pandas as pd
df_merchant=pd.read_excel("merchant_details.xlsx")
df_merchant.head()
# Out:
#       _id                    name       doing_business_as   pan_number  \
# 0   43968  SHREE TIKULIGADH MA VI  SHREE TIKULIGADH MA VI  912345704.0
# 1    8650  ARJUN SUNCHANDI UDHYOG  ARJUN SUNCHANDI UDHYOG  602205809.0
# 2  306428      PINKY KABADI PASAL      PINKY KABADI PASAL  301463056.0
# 3   32681    CRYSTAL OFFSET PRESS    CRYSTAL OFFSET PRESS  304298275.0
# 4  283430     MUNNI LAL MANGI LAL     MUNNI LAL MANGI LAL  301454342.0
#
#    mobile_number                  email_id    account_number  \
# 0     9857015912       9857015912@nica.com  F141000445852402
# 1     9856042369  sunitasunar352@gmail.com  E641000443952402
# 2     9815993973            sekh@gmail.com  P541000445452402
# 3     9843159014  crystal.press6@gmail.com  0841827246052401
# 4     9855022111      9855022111@gmail.com  2240133473524004
#
#              account_name                 user_name  status  ...  \
# 0  SHREE TIKULIGADH MA VI       9857015912@nica.com  ACTIVE  ...
# ...

# %%
df_acid_for=pd.read_csv("")
